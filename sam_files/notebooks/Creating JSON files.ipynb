# %% [markdown]
# ### 1) Load files and .csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

csv_path = "/content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/Bon _Export_20k_full_tags.csv"

df = pd.read_csv(csv_path)

classical_df = pd.read_csv('/content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/500_classical_tracks.csv')
lofi_df = pd.read_csv('/content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/500_lofi_tracks.csv')

# %% [markdown]
# #### 1.1) dataset for testing

# %%
#test_df = classical_df[:20]
#test_df.to_csv('/content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/test_df.csv')

# %% [markdown]
# ### 2) Create .json files

# %%
import pandas as pd
import json
import os
import re
from collections import Counter
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import CountVectorizer
import nltk

# Download the 'wordnet' resource
nltk.download('wordnet')

# Initialize the lemmatizer
lemmatizer = nltk.WordNetLemmatizer()

def extract_ngrams(text, n):
    """
    Extract n-grams from a given text.

    Parameters:
    - text: A string of text.
    - n: The number of words in the n-gram.

    Returns:
    - A list of n-grams.
    """
    vectorizer = CountVectorizer(ngram_range=(n, n), stop_words=None)
    analyzer = vectorizer.build_analyzer()
    return analyzer(text)

def is_meaningful_phrase(phrase):
    """
    Check if a phrase is meaningful by verifying its components.

    Parameters:
    - phrase: A string representing the phrase.

    Returns:
    - True if the phrase is meaningful, False otherwise.
    """
    words = phrase.split()
    # Check if the individual words are meaningful and make sense together
    for word in words:
        if not wn.synsets(word):
            return False
    return True

def find_common_phrases(df, columns, min_count=5):
    """
    Find common phrases (bigrams and trigrams) in the specified columns of the dataframe.

    Parameters:
    - df: The input dataframe.
    - columns: List of column names to process.
    - min_count: Minimum count to consider a phrase as common.

    Returns:
    - A set of common phrases.
    """
    phrases = []
    for col in columns:
        for text in df[col].dropna():
            phrases.extend(extract_ngrams(text.lower(), 2))  # Bigrams
            phrases.extend(extract_ngrams(text.lower(), 3))  # Trigrams

    phrase_counts = Counter(phrases)
    common_phrases = {phrase for phrase, count in phrase_counts.items() if count >= min_count and is_meaningful_phrase(phrase)}
    return common_phrases

def process_keywords(row, columns, common_phrases):
    """
    Concatenate and process keywords from specified columns, splitting by newline characters.

    Parameters:
    - row: A pandas Series representing a row in the dataframe.
    - columns: List of column names to process.
    - common_phrases: Set of common phrases to preserve as composite keywords.

    Returns:
    - A string containing concatenated keywords.
    """
    exclude_keywords = {'main', 'title'}
    keywords = []
    composite_keywords = []

    for col in columns:
        if pd.notna(row[col]):
            words = row[col].replace('\n', ' ').lower().split()
            words = [word for word in words if word not in exclude_keywords and len(word) > 2]  # Exclude single chars and common keywords
            if words:
                # Identify and preserve composite keywords
                composite = {phrase for phrase in common_phrases if phrase in row[col].lower()}
                composite_keywords.extend(composite)
                for composite_kw in composite:
                    if composite_kw not in keywords:
                        keywords.append(composite_kw)

                # Add remaining single words
                for word in words:
                    if word not in keywords:
                        keywords.append(word)

    # Create a list of unique keywords and phrases
    unique_keywords = []
    for kw in composite_keywords:
        if all(kw not in other_kw for other_kw in unique_keywords):
            unique_keywords.append(kw)

    unique_keywords.extend([kw for kw in keywords if kw not in unique_keywords])

    # Select keywords by type, ensuring no overlap
    three_word_phrases = [kw for kw in unique_keywords if len(kw.split()) == 3][:4]
    two_word_phrases = [kw for kw in unique_keywords if len(kw.split()) == 2 and all(kw not in three_word for three_word in three_word_phrases)][:3]
    single_words = [kw for kw in unique_keywords if len(kw.split()) == 1 and all(kw not in two_word for two_word in two_word_phrases)][:8]

    # Combine all keywords and join into a single string
    final_keywords = three_word_phrases + two_word_phrases + single_words

    return ', '.join(final_keywords)

def sanitize_filename(name):
    """
    Sanitize the filename to remove or replace invalid characters.

    Parameters:
    - name: The original filename string.

    Returns:
    - A sanitized filename string.
    """
    # Replace invalid characters with an underscore
    return re.sub(r'[<>:"/\\|?*]', '_', name)

def create_json_files(csv_path, output_dir):
    """
    Create JSON files from a CSV dataset.

    Parameters:
    - csv_path: Path to the input CSV file.
    - output_dir: Directory where JSON files will be saved.
    """
    # Read CSV file
    df = pd.read_csv(csv_path)

    # Columns to process
    columns = ['Genre', 'Mood', 'Movement', 'Theme', 'Other keywords', 'Other keywords.1']

    # Find common phrases in the dataset
    common_phrases = find_common_phrases(df, columns)

    # Create output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Process each row and create JSON files
    for index, row in df.iterrows():
        prompt = process_keywords(row, columns, common_phrases)

        # Use the 'Title' column value as the filename, sanitize it for filesystem
        title = row.get('Title', f'file_{index+1}').strip()
        sanitized_title = sanitize_filename(title)
        file_name = f"{index+1}_{sanitized_title}.json"
        file_path = os.path.join(output_dir, file_name)

        # Prepare the data to be saved in JSON
        data = {"prompt": prompt}

        # Write JSON file
        with open(file_path, 'w') as f:
            json.dump(data, f, indent=4)

        print(f"Created {file_path}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Usage example
csv_path = '/content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/500_lofi_tracks.csv'  # Update with your CSV file path
output_dir = '/content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_lofi/'  # Update with your desired output directory

create_json_files(csv_path, output_dir)

# %% [markdown]
# ### Testing new code - 18h39, 06/08/2024

# %%
import pandas as pd
import json
import os
import re
from collections import Counter
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
import nltk

# Download the 'wordnet' resource
nltk.download('wordnet')

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

def extract_ngrams(text, n):
    """
    Extract n-grams from a given text.

    Parameters:
    - text: A string of text.
    - n: The number of words in the n-gram.

    Returns:
    - A list of n-grams.
    """
    vectorizer = CountVectorizer(ngram_range=(n, n), stop_words=None)
    analyzer = vectorizer.build_analyzer()
    return analyzer(text)

def find_common_phrases(df, columns, min_count=5):
    """
    Find common phrases (bigrams and trigrams) in the specified columns of the dataframe.

    Parameters:
    - df: The input dataframe.
    - columns: List of column names to process.
    - min_count: Minimum count to consider a phrase as common.

    Returns:
    - A set of common phrases.
    """
    phrases = []
    for col in columns:
        for text in df[col].dropna():
            phrases.extend(extract_ngrams(text.lower(), 2))  # Bigrams
            phrases.extend(extract_ngrams(text.lower(), 3))  # Trigrams

    phrase_counts = Counter(phrases)
    common_phrases = {phrase for phrase, count in phrase_counts.items() if count >= min_count}
    return common_phrases

def process_keywords(row, columns, common_phrases):
    """
    Concatenate and process keywords from specified columns, splitting by newline characters.

    Parameters:
    - row: A pandas Series representing a row in the dataframe.
    - columns: List of column names to process.
    - common_phrases: Set of common phrases to preserve as composite keywords.

    Returns:
    - A string containing concatenated keywords.
    """
    exclude_keywords = {'main', 'title'}
    keywords = []
    composite_keywords = []

    for col in columns:
        if pd.notna(row[col]):
            words = row[col].replace('\n', ' ').lower().split()
            words = [word for word in words if word not in exclude_keywords and len(word) > 1]  # Exclude single chars and common keywords
            if words:
                # Identify and preserve composite keywords
                composite = {phrase for phrase in common_phrases if phrase in row[col].lower()}
                composite_keywords.extend(composite)
                for composite_kw in composite:
                    if composite_kw not in keywords:
                        keywords.append(composite_kw)

                # Add remaining single words
                for word in words:
                    if word not in keywords:
                        keywords.append(word)

    # Create a list of unique keywords and phrases
    unique_keywords = []
    for kw in composite_keywords:
        if all(kw not in other_kw for other_kw in unique_keywords):
            unique_keywords.append(kw)

    unique_keywords.extend([kw for kw in keywords if kw not in unique_keywords])

    # Select keywords by type, ensuring no overlap
    three_word_phrases = [kw for kw in unique_keywords if len(kw.split()) == 3][:3]
    two_word_phrases = [kw for kw in unique_keywords if len(kw.split()) == 2 and kw not in three_word_phrases][:3]
    single_words = [kw for kw in unique_keywords if len(kw.split()) == 1 and kw not in two_word_phrases][:4]

    # Combine all keywords and join into a single string
    final_keywords = three_word_phrases + two_word_phrases + single_words

    return ', '.join(final_keywords)

def sanitize_filename(name):
    """
    Sanitize the filename to remove or replace invalid characters.

    Parameters:
    - name: The original filename string.

    Returns:
    - A sanitized filename string.
    """
    # Replace invalid characters with an underscore
    return re.sub(r'[<>:"/\\|?*]', '_', name)

def create_json_files(csv_path, output_dir):
    """
    Create JSON files from a CSV dataset.

    Parameters:
    - csv_path: Path to the input CSV file.
    - output_dir: Directory where JSON files will be saved.
    """
    # Read CSV file
    df = pd.read_csv(csv_path)

    # Columns to process
    columns = ['Genre', 'Mood', 'Movement', 'Theme', 'Other keywords', 'Other keywords.1']

    # Find common phrases in the dataset
    common_phrases = find_common_phrases(df, columns)

    # Create output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Process each row and create JSON files
    for index, row in df.iterrows():
        prompt = process_keywords(row, columns, common_phrases)

        # Use the 'Title' column value as the filename, sanitize it for filesystem
        title = row.get('Title', f'file_{index+1}').strip()
        sanitized_title = sanitize_filename(title)
        file_name = f"{index+1}_{sanitized_title}.json"
        file_path = os.path.join(output_dir, file_name)

        # Prepare the data to be saved in JSON
        data = {"prompt": prompt}

        # Write JSON file
        with open(file_path, 'w') as f:
            json.dump(data, f, indent=4)

        print(f"Created {file_path}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Usage example
csv_path = '/content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/500_classical_tracks.csv'  # Update with your CSV file path
output_dir = '/content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/'  # Update with your desired output directory

create_json_files(csv_path, output_dir)
# Out:
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/1_Inspiring Cinematic Ambient.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/2_Risk.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/3_Science Documentary.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/4_Majestic Voyage.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/5_Drive to Triumph.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/6_Motivational Epic Music _ Inspiring Cinematic Background Music.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/7_Awaken.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/8_Price of Freedom.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/9_Waterfall.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/10_Reflected Light.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/11_Winning Elevation.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/12_Relaxing.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/13_Eco Technology.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/14_Cinematic Time Lapse.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/15_Rise Above.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/16_Unlimited Motivation.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/17_Power Play.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/18_Piano Moment.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/19_Winter Legacy. The Four Seasons. Hip-Hop version. Background music.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/20_Battlefield Elegy.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/21_Epic Emotional_Long.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/22_Loves Serenade.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/23_Beautiful Piano Music - felt piano [Now We Are Free].json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2
json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/426_The Story Unfolds (Cinematic Move Background Music).json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/427_Cinematic Dramatic Documentary Piano.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/428_Piano and Nature Sounds.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/429_Cinematic Epical Day.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/430_Peaceful Ripples.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/431_live long enough and become a villain.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/432_Angel Piano (Main).json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/433_Vivaldi - Four Seasons _Winter_ - RV 297 - Arr. for Strings.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/434_Creative Rise_40sec.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/435_Cheerful light waltz for short video vlog, advertising, promo 40 sec.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/436_Epic background piano music for short video vlog, advertising 1 minute.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/437_The Adventures of Mr. Hardy_60sec.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/438_Deep Cinematic Ballad_36sec.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/439_Idea 15.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/440_moon weasel - Piano Music.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/441_Blessed  (EXTENDED VERSION).json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/442_Forget.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/443_Beethoven - Moonlight Sonata (1. Movement) - Op. 27, Nr. 2.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/444_Blessed (Main).json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/445_Apocalypse_v1_60sec.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/446_Middle Ages.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/447_The Wrath Of The Samurai.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/448_The Epic Intro Music.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/449_Background music for short video vlog. Funny light accompanying.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/450_Pictures of Memories.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/451_Sad Piano - Background Music For Videos.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/452_Sentimental Action.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/453_Dramatic Suspense.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/454_Ancient Legend.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/455_Calm and Peaceful.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/456_Fearsome Tipsy Pirates ( Pirates Epic Trailer ).json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/457_Illuminati - weird piano meme.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/464_journeys of the soul.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/465_peace - piano song.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/466_History In The Heart.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/467_A Sinister Power Rising - Epic Dark Gothic Soundtrack.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/468_Inspiring Landscape.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/469_Epic music, background instrumental for video. Dramatic Hip Hop beat.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/470_beneath the infinite sky.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/471_Documentary Background.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/472_Soft adventure classical instrumental.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/473_Lovely Moment.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/474_We wish you a Merry Christmas_56sec.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/475_Gravity.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/476_Daybreak Melody.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/477_Cheerful Cinematic Song (without solo guitar).json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/478_Epic Colors.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/479_Resistance.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/480_Silver Sparkles.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/481_Magic Christmas_60sec.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/482_Ominous Tension.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/483_World Travel.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/484_Ten Minutes of Ambient Piano Relaxation.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/485_Sky Dive.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/486_Action Intro Trailer.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/487_The HIdden Diamonds.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/488_Magic Christmas_24sec.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/489_Magic Christmas_36sec.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/490_Sad Piano and Violin.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/491_Inspirational Drama.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/492_Hybrid Trailer Epic.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/493_Endless World.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/494_For Documentary.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/495_The Power Within.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/496_TIME (Long version).json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/497_Magic Inspiration.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/498_Cinematic Dark Trailer_41sec.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/499_Tension.json
# Created /content/drive/MyDrive/_France-Paris 2020/Data Scientist/S.A.M/S.A.M/Modèles/data/json_files_classical2/500_Two Silly Monkeys.json

# %% [markdown]
# ### 4) Verify first row from table

# %%
# Columns to print
columns = ['Genre', 'Mood', 'Movement', 'Theme', 'Other keywords', 'Other keywords.1']

# Print the specified columns for the first row
first_row = lofi_df.loc[0, columns]

# Replace newline characters with spaces
first_row = first_row.apply(lambda x: x.replace('\n', ' ') if isinstance(x, str) else x)

# Save the specified columns for the first row to a file
output_path = '/content/first_row_output.txt'
with open(output_path, 'w') as f:
    f.write("First row values for specified columns:\n")
    for col in columns:
        # Limit the length of the printed content to avoid very long lines
        value = first_row[col]
        if isinstance(value, str) and len(value) > 100:
            value = value[:100] + '...'
        f.write(f"{col}: {value}\n")

print(f"Output saved to {output_path}")
# Out:
# Output saved to /content/first_row_output.txt
