# %% [markdown]
# # 5 - Uploading to S.A.M. bucket

# %% [markdown]
# ## 1. Load .env variables

# %%
from dotenv import load_dotenv
import os

load_dotenv()

GITHUB_PROFILE_NAME = os.getenv('GITHUB_PROFILE_NAME')
genre = os.getenv('genre')
file_count = os.getenv('file_count')

# %% [markdown]
# ## 2. Move manually your .JSON credential
#   - In SAM Google Drive, go in data/sam-gcp
#   - Put your json-credential.json in /sam_files
#   - Open the .env for sam_files (sam_files/notebooks/dataset for fine-tuning/.env)
#   - insert this line :
#     - `gcp_api_json_path={json-credential.json}` (it's already in sam_files)

# %% [markdown]
# ## 3. Uploading to Google Cloud Bucket

# %% [markdown]
# ### 3.1. You need to be in :
#   - `../stable-audio-tools-sam/sam_files`

# %%
# %cd ..
# %cd ..
# Out:
# /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files/notebooks
# /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files

# %% [markdown]
# ### 3.2. Copying folders to bucket

# %%
# %%bash
#
# # Replace with your actual bucket name
# bucket_name="sam-dataset"
#
# # Get the current timestamp
# timestamp=$(date +"%Y-%m-%d_%H-%M-%S")
#
# # Create the folder name within the bucket
# folder_name="${file_count}_${genre}_files_${timestamp}"
#
# #capture variables
# echo "bucket_name=$bucket_name" >> "notebooks/dataset for fine-tuning/.env"
# echo "timestamp=$timestamp" >> "notebooks/dataset for fine-tuning/.env"
# echo "folder_name=$folder_name" >> "notebooks/dataset for fine-tuning/.env"
#
# # List of source folders you want to upload
# source_folders=("json" "dataframes" "audio_files")
#
# # Upload each folder to the bucket
# for source_folder in "${source_folders[@]}"
# do
#     gsutil -m cp -r -L "upload_log_${timestamp}.txt" "$source_folder" "gs://$bucket_name/$folder_name/"
# done
# Out:
# Copying file://json/json_classical/361_Epic background music for short video Dramatic orchestral instrumental.json [Content-Type=application/json]...
# Copying file://json/json_classical/334_아기들의 자장가2.json [Content-Type=application/json]...
# Copying file://json/json_classical/274_Uống Nước Nhớ Nguồn - Piano BGM.json [Content-Type=application/json]...
# Copying file://json/json_classical/350_Legacy of Chopin. Nocturne No. 20 Hip-Hop version. Background music.json [Content-Type=application/json]...
# Copying file://json/json_classical/271_Dưới Ánh Trăng Yêu Thương - Nhạc Nền Video.json [Content-Type=application/json]...
# Copying file://json/json_classical/260_Epic Motivational Trailer.json [Content-Type=application/json]...
# Copying file://json/json_classical/46_Cinematic Fairy Tale Story (Main).json [Content-Type=application/json]...
# Copying file://json/json_classical/113_Cinematic Action Intro.json [Content-Type=application/json]...
# Copying file://json/json_classical/364_piano Music -Lose Control.json [Content-Type=application/json]...
# Copying file://json/json_classical/243_Apocalypse_v3_59sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/164_Solas.json [Content-Type=application/json]...
# Copying file://json/json_classical/389_Christmas In the Village.json [Content-Type=application/json]...
# Copying file://json/json_classical/53_Meeting the Stars. Dramatic cinematic background music for epic video.json [Content-Type=application/json]...
# Copying file://json/json_classical/198_Uplifting Piano Is.json [Content-Type=application/json]...
# Copying file://json/json_classical/178_Shooting stars.json [Content-Type=application/json]...
# Copying file://json/json_classical/157_Fortnight - peaceful piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/20_Battlefield Elegy.json [Content-Type=application/json]...
# Copying file://json/json_classical/455_Calm and Peaceful.json [Content-Type=application/json]...
# Copying file://json/json_classical/272_Vũ Điệu Của Những Vì Sao - Relaxing Piano For Youtube Video.json [Content-Type=application/json]...
# Copying file://json/json_classical/429_Cinematic Epical Day.json [Content-Type=application/json]...
# Copying file://json/json_classical/425_Calm Fantasy Harp and Strings.json [Content-Type=application/json]...
# Copying file://json/json_classical/346_Deep in the Dell.json [Content-Type=application/json]...
# Copying file://json/json_classical/359_Beautiful Trip.json [Content-Type=application/json]...
# Copying file://json/json_classical/202_Emotional Cinematic_34sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/299_Lost in the Enchanted Woods.json [Content-Type=application/json]...
# Copying file://json/json_classical/326_Funny music background for video, stories. Positive spring day 30 sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/176_Love Story (Sentimental Emotional).json [Content-Type=application/json]...
# Copying file://json/json_classical/150_Victorian Violin Waltz.json [Content-Type=application/json]...
# Copying file://json/json_classical/117_One love story. Orchestral hip-hop version. Background music for video.json [Content-Type=application/json]...
# Copying file://json/json_classical/38_Epic Action.json [Content-Type=application/json]...
# Copying file://json/json_classical/34_Loneliness_Long.json [Content-Type=application/json]...
# Copying file://json/json_classical/173_Cozy Autumn - Beautiful Piano Song.json [Content-Type=application/json]...
# Copying file://json/json_classical/388_The King_60sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/432_Angel Piano (Main).json [Content-Type=application/json]...
# Copying file://json/json_classical/478_Epic Colors.json [Content-Type=application/json]...
# Copying file://json/json_classical/142_Tập Trung Cao Độ Khi Làm Việc - Piano BGM.json [Content-Type=application/json]...
# Copying file://json/json_classical/416_My Love_34sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/434_Creative Rise_40sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/80_Storm Rising.json [Content-Type=application/json]...
# Copying file://json/json_classical/355_Blockbuster Trailer Ident.json [Content-Type=application/json]...
# Copying file://json/json_classical/223_Trapped Flames.json [Content-Type=application/json]...
# Copying file://json/json_classical/82_Emotional Cinematic Inspirational Piano (MAIN).json [Content-Type=application/json]...
# Copying file://json/json_classical/382_🎹Contemporary Classical _ _Serenity's Sonata II_.json [Content-Type=application/json]...
# Copying file://json/json_classical/254_We wish you a Merry Christmas_60sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/456_Fearsome Tipsy Pirates ( Pirates Epic Trailer ).json [Content-Type=application/json]...
# Copying file://json/json_classical/474_We wish you a Merry Christmas_56sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/228_Story of Heroes.json [Content-Type=application/json]...
# Copying file://json/json_classical/39_Thinking Of Good Time - Soft Piano Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/12_Relaxing.json [Content-Type=application/json]...
# Copying file://json/json_classical/147_Bỏ Phố Thị Ta Trở Về Với Thôn Quê - Piano Cafe.json [Content-Type=application/json]...
# Copying file://json/json_classical/252_Inspiring Epic Fly (Cinematic Action Triumphant).json [Content-Type=application/json]...
# Copying file://json/json_classical/362_Believe In Yourself (Inspiring Piano Hopeful Epic Trailer).json [Content-Type=application/json]...
# Copying file://json/json_classical/440_moon weasel - Piano Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/21_Epic Emotional_Long.json [Content-Type=application/json]...
# Copying file://json/json_classical/186_Für Elise - Beethoven.json [Content-Type=application/json]...
# Copying file://json/json_classical/415_Background music for video 21 sec. Legacy of Chopin Nocturne op.9 No.2.json [Content-Type=application/json]...
# Copying file://json/json_classical/143_Hoà Tấu Nhẹ Nhàng Tập Trung Làm Việc - Piano Cafe.json [Content-Type=application/json]...
# Copying file://json/json_classical/461_Cinematic Motivational.json [Content-Type=application/json]...
# Copying file://json/json_classical/494_For Documentary.json [Content-Type=application/json]...
# Copying file://json/json_classical/23_Beautiful Piano Music - felt piano [Now We Are Free].json [Content-Type=application/json]...
# Copying file://json/json_classical/155_Beethoven - Concert Nr3 (Relaxing Classical Piano).json [Content-Type=application/json]...
# Copying file://json/json_classical/375_Nature.json [Content-Type=application/json]...
# Copying file://json/json_classical/426_The Story Unfolds (Cinematic Move Background Music).json [Content-Type=application/json]...
# Copying file://json/json_classical/94_Countdown.json [Content-Type=application/json]...
# Copying file://json/json_classical/485_Sky Dive.json [Content-Type=application/json]...
# Copying file://json/json_classical/44_Award - Adventure Epic Inspiring Cinematic Orchestra.json [Content-Type=application/json]...
# Copying file://json/json_classical/5_Drive to Triumph.json [Content-Type=application/json]...
# Copying file://json/json_classical/218_Climax - Epic Sad Piano Song.json [Content-Type=application/json]...
# Copying file://json/json_classical/297_Beautiful Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/19_Winter Legacy. The Four Seasons. Hip-Hop version. Background music.json [Content-Type=application/json]...
# Copying file://json/json_classical/207_Epic Cinematic Intro_26sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/74_My Love Medium.json [Content-Type=application/json]...
# Copying file://json/json_classical/421_The Crystal Cave.json [Content-Type=application/json]...
# Copying file://json/json_classical/197_Epic inspirational  Cinematic Trailer.json [Content-Type=application/json]...
# Copying file://json/json_classical/168_Warrior_59sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/246_Softer Love.json [Content-Type=application/json]...
# Copying file://json/json_classical/219_Let's get this done.json [Content-Type=application/json]...
# Copying file://json/json_classical/403_Epic Cinematic Intro_60sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/378_Powerful Emotional Epic.json [Content-Type=application/json]...
# Copying file://json/json_classical/465_peace - piano song.json [Content-Type=application/json]...
# Copying file://json/json_classical/317_Peaceful Cinematic.json [Content-Type=application/json]...
# Copying file://json/json_classical/130_Winter Legacy. The Four Seasons Antonio Vivaldi Hip-Hop version 33 sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/15_Rise Above.json [Content-Type=application/json]...
# Copying file://json/json_classical/160_Lost Illusions (Emotional Cinematic Orchestra).json [Content-Type=application/json]...
# Copying file://json/json_classical/336_Spellcraft.json [Content-Type=application/json]...
# Copying file://json/json_classical/280_Ánh Sáng Nhỏ Trong Bóng Đêm - Relaxing Piano For Youtube Video.json [Content-Type=application/json]...
# Copying file://json/json_classical/458_Gravity.json [Content-Type=application/json]...
# Copying file://json/json_classical/396_A Thousand Times.json [Content-Type=application/json]...
# Copying file://json/json_classical/149_Mình Cùng Về Quê Xây Căn Nhà Nhỏ - Piano BGM.json [Content-Type=application/json]...
# Copying file://json/json_classical/196_Virtuoso.json [Content-Type=application/json]...
# Copying file://json/json_classical/479_Resistance.json [Content-Type=application/json]...
# Copying file://json/json_classical/290_Wedding Hopeful Cinematic Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/195_Melody of Nature (Main).json [Content-Type=application/json]...
# Copying file://json/json_classical/175_Militant Amelia. Dramatic orchestral background music for video 34 sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/459_The Calm Ocean.json [Content-Type=application/json]...
# Copying file://json/json_classical/28_Epicaly.json [Content-Type=application/json]...
# Copying file://json/json_classical/66_Moon Rain - Beautiful Piano Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/170_Song From A Secret Garden (Sad Piano).json [Content-Type=application/json]...
# Copying file://json/json_classical/311_Dark - Action Aggressive Anxiety Horror Countdown Trailer Intro.json [Content-Type=application/json]...
# Copying file://json/json_classical/92_Inspirational Sentimental Romantic.json [Content-Type=application/json]...
# Copying file://json/json_classical/306_My Little Garden of Eden.json [Content-Type=application/json]...
# Copying file://json/json_classical/471_Documentary Background.json [Content-Type=application/json]...
# Copying file://json/json_classical/31_morning in the mountains.json [Content-Type=application/json]...
# Copying file://json/json_classical/3_Science Documentary.json [Content-Type=application/json]...
# Copying file://json/json_classical/319_Inspirational Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/183_Loneliness_51sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/277_Peaceful Piano Music - Piano BGM.json [Content-Type=application/json]...
# Copying file://json/json_classical/287_Magic Christmas_Medium.json [Content-Type=application/json]...
# Copying file://json/json_classical/473_Lovely Moment.json [Content-Type=application/json]...
# Copying file://json/json_classical/227_Inspiring Cinematic Asia.json [Content-Type=application/json]...
# Copying file://json/json_classical/325_Never Leave.json [Content-Type=application/json]...
# Copying file://json/json_classical/431_live long enough and become a villain.json [Content-Type=application/json]...
# Copying file://json/json_classical/234_twentieth of august [calm piano].json [Content-Type=application/json]...
# Copying file://json/json_classical/372_Emotional Connection.json [Content-Type=application/json]...
# Copying file://json/json_classical/231_Romantic Love Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/500_Two Silly Monkeys.json [Content-Type=application/json]...
# Copying file://json/json_classical/345_Inspiring Uplifting Cinematic Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/490_Sad Piano and Violin.json [Content-Type=application/json]...
# Copying file://json/json_classical/408_Time Has Come.json [Content-Type=application/json]...
# Copying file://json/json_classical/107_Militant Amelia. Dramatic background music for video vlog 1 minute.json [Content-Type=application/json]...
# Copying file://json/json_classical/240_Creative Rise_Medium.json [Content-Type=application/json]...
# Copying file://json/json_classical/379_the first star -Calm Relaxing Piano Solo Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/258_Majestic - Dark Epic Motivational Uplifting Tense Orchestra.json [Content-Type=application/json]...
# Copying file://json/json_classical/464_journeys of the soul.json [Content-Type=application/json]...
# Copying file://json/json_classical/217_Loneliness_36sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/72_Winter Legacy. The Four Seasons Antonio Vivaldi Hip-Hop version 54 sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/29_Sad Waltz  - Mia and Sebastian’s Theme [Piano].json [Content-Type=application/json]...
# Copying file://json/json_classical/451_Sad Piano - Background Music For Videos.json [Content-Type=application/json]...
# Copying file://json/json_classical/320_Loyalty To The Crown_40sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/78_Cinematic Documentary Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/212_The Flashback_60sec 2.json [Content-Type=application/json]...
# Copying file://json/json_classical/401_Cinematic Dark Trailer_57sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/470_beneath the infinite sky.json [Content-Type=application/json]...
# Copying file://json/json_classical/60_Beyond Horizons.json [Content-Type=application/json]...
# Copying file://json/json_classical/221_Passacaglia.json [Content-Type=application/json]...
# Copying file://json/json_classical/171_Mặt Nước Tĩnh Lặng Cảm Thấy Thật Bình Yên - Nhạc Nền Video.json [Content-Type=application/json]...
# Copying file://json/json_classical/467_A Sinister Power Rising - Epic Dark Gothic Soundtrack.json [Content-Type=application/json]...
# Copying file://json/json_classical/30_Solas x Interstellar.json [Content-Type=application/json]...
# Copying file://json/json_classical/194_Da Vinci_Medium 2.json [Content-Type=application/json]...
# Copying file://json/json_classical/69_Epic Emotional_Short 1.json [Content-Type=application/json]...
# Copying file://json/json_classical/174_Cinematic Ambient Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/67_Broken Sonata - Sad Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/33_Afterglow - Atmospheric Cinematic Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/136_Loneliness_Medium 2.json [Content-Type=application/json]...
# Copying file://json/json_classical/70_The Last Watchman (Epic Cinematic Noir Orchestra).json [Content-Type=application/json]...
# Copying file://json/json_classical/300_Deep Cinematic Ballad_Medium.json [Content-Type=application/json]...
# Copying file://json/json_classical/322_Renaissance (Epic Orchestral Cinematic).json [Content-Type=application/json]...
# Copying file://json/json_classical/81_Anthem of Victory.json [Content-Type=application/json]...
# Copying file://json/json_classical/422_Crazy Mind - piano music.json [Content-Type=application/json]...
# Copying file://json/json_classical/16_Unlimited Motivation.json [Content-Type=application/json]...
# Copying file://json/json_classical/36_Let the Mystery Unfold.json [Content-Type=application/json]...
# Copying file://json/json_classical/172_A Gentle Breeze.json [Content-Type=application/json]...
# Copying file://json/json_classical/57_Bỏ Phố Về Quê - Relaxing Piano For Youtube Video.json [Content-Type=application/json]...
# Copying file://json/json_classical/360_Shots Of Memories.json [Content-Type=application/json]...
# Copying file://json/json_classical/330_whisper in the rain.json [Content-Type=application/json]...
# Copying file://json/json_classical/427_Cinematic Dramatic Documentary Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/419_Find Your Zen 2.json [Content-Type=application/json]...
# Copying file://json/json_classical/395_Say Yes to Heaven.json [Content-Type=application/json]...
# Copying file://json/json_classical/352_Hiding place in the Forest.json [Content-Type=application/json]...
# Copying file://json/json_classical/18_Piano Moment.json [Content-Type=application/json]...
# Copying file://json/json_classical/344_Triumphant (Long).json [Content-Type=application/json]...
# Copying file://json/json_classical/436_Epic background piano music for short video vlog, advertising 1 minute.json [Content-Type=application/json]...
# Copying file://json/json_classical/182_Deep Cinematic Ballad_60sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/11_Winning Elevation.json [Content-Type=application/json]...
# Copying file://json/json_classical/368_June Medium.json [Content-Type=application/json]...
# Copying file://json/json_classical/111_Out of Time.json [Content-Type=application/json]...
# Copying file://json/json_classical/278_Tư Duy Sáng Tạo Tại Văn Phòng Công Ty - Nhạc Nền Video.json [Content-Type=application/json]...
# Copying file://json/json_classical/239_I Giorni.json [Content-Type=application/json]...
# Copying file://json/json_classical/37_Warrior_Medium.json [Content-Type=application/json]...
# Copying file://json/json_classical/293_Dramatic Horror Cinematic Epic Trailer Action Intro Opener.json [Content-Type=application/json]...
# Copying file://json/json_classical/288_Inspirational Epic.json [Content-Type=application/json]...
# Copying file://json/json_classical/417_The King_30sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/441_Blessed  (EXTENDED VERSION).json [Content-Type=application/json]...
# Copying file://json/json_classical/189_Warrior's Peace.json [Content-Type=application/json]...
# Copying file://json/json_classical/391_Epic piano background music for video vlog, blog, advertising 1 minute.json [Content-Type=application/json]...
# Copying file://json/json_classical/397_The Lights of the Village.json [Content-Type=application/json]...
# Copying file://json/json_classical/89_Về Quê Nuôi Cá Trồng Rau An Nhàn.json [Content-Type=application/json]...
# Copying file://json/json_classical/41_Inspiring Emotional Uplifting Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/341_Endless Beauty (Main).json [Content-Type=application/json]...
# Copying file://json/json_classical/343_The Magic Tree.json [Content-Type=application/json]...
# Copying file://json/json_classical/102_Lost Dreams - Inspiring Cinematic Ambient.json [Content-Type=application/json]...
# Copying file://json/json_classical/127_Emotional Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/154_Constellation of Future Memories [Beautiful Piano].json [Content-Type=application/json]...
# Copying file://json/json_classical/40_Cinematic Dramatic.json [Content-Type=application/json]...
# Copying file://json/json_classical/398_Symphony of Emotion (1).json [Content-Type=application/json]...
# Copying file://json/json_classical/115_Heroes among us. Orchestral hip-hop version Background music for video.json [Content-Type=application/json]...
# Copying file://json/json_classical/105_Alice in Dark Wonderland.json [Content-Type=application/json]...
# Copying file://json/json_classical/177_Background music for video, promo, stories. Positive spring day 27 sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/52_Cute Creatures.json [Content-Type=application/json]...
# Copying file://json/json_classical/495_The Power Within.json [Content-Type=application/json]...
# Copying file://json/json_classical/329_Romantic piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/215_Inspiring Cinematic.json [Content-Type=application/json]...
# Copying file://json/json_classical/97_Winter Legacy. The Four Seasons Antonio Vivaldi Hip-Hop version 21 sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/153_Epic Cinematic Intro_Medium 2.json [Content-Type=application/json]...
# Copying file://json/json_classical/138_Cinematic Piano - Epic Hopes.json [Content-Type=application/json]...
# Copying file://json/json_classical/124_Meeting the Stars. Epic background orchestral music for video 1 min.json [Content-Type=application/json]...
# Copying file://json/json_classical/255_evening glow - Beautiful Piano Music For Videos.json [Content-Type=application/json]...
# Copying file://json/json_classical/98_Era of Cyborgs. Orchestral Slap House. Background music for video.json [Content-Type=application/json]...
# Copying file://json/json_classical/435_Cheerful light waltz for short video vlog, advertising, promo 40 sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/133_Da Vinci_Short.json [Content-Type=application/json]...
# Copying file://json/json_classical/86_Không Gian Làm Việc Lí Tưởng - Piano Relaxing (Instagram Music).json [Content-Type=application/json]...
# Copying file://json/json_classical/17_Power Play.json [Content-Type=application/json]...
# Copying file://json/json_classical/366_Busy Bees.json [Content-Type=application/json]...
# Copying file://json/json_classical/266_Apocalypse.json [Content-Type=application/json]...
# Copying file://json/json_classical/87_Con Nước Trôi Miên Mang Đưa Ta Vào Chốn Phiêu Bồng - Piano Cafe.json [Content-Type=application/json]...
# Copying file://json/json_classical/453_Dramatic Suspense.json [Content-Type=application/json]...
# Copying file://json/json_classical/83_Dòng Nước Trôi Yên Ả Mát Lành - Piano Cafe.json [Content-Type=application/json]...
# Copying file://json/json_classical/483_World Travel.json [Content-Type=application/json]...
# Copying file://json/json_classical/439_Idea 15.json [Content-Type=application/json]...
# Copying file://json/json_classical/267_Evening Breeze.json [Content-Type=application/json]...
# Copying file://json/json_classical/489_Magic Christmas_36sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/296_Wander.json [Content-Type=application/json]...
# Copying file://json/json_classical/414_Deep Cinematic Ballad_37sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/407_War is Coming.json [Content-Type=application/json]...
# Copying file://json/json_classical/263_Legacy of Chopin. Nocturne op.9 No.2 Hip-Hop version. Background music.json [Content-Type=application/json]...
# Copying file://json/json_classical/8_Price of Freedom.json [Content-Type=application/json]...
# Copying file://json/json_classical/337_Medieval Life.json [Content-Type=application/json]...
# Copying file://json/json_classical/139_dialogues with the past.json [Content-Type=application/json]...
# Copying file://json/json_classical/284_Mặt Hồ Phẳng Lặng Như Gương Phản Chiếu Bầu Trời Trong Vắt - Piano Cafe.json [Content-Type=application/json]...
# Copying file://json/json_classical/484_Ten Minutes of Ambient Piano Relaxation.json [Content-Type=application/json]...
# Copying file://json/json_classical/112_big dreams, small steps.json [Content-Type=application/json]...
# Copying file://json/json_classical/309_My Love_43sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/90_Waltz in A Minor - Chopin (Classical Piano).json [Content-Type=application/json]...
# Copying file://json/json_classical/339_Dramatic Documentary Cinematic Suspense - Coming For You (Short Ver.).json [Content-Type=application/json]...
# Copying file://json/json_classical/384_Chạm Vào Trái Tim Bằng Nốt Nhạc - Piano Cafe.json [Content-Type=application/json]...
# Copying file://json/json_classical/323_Epic Piano Music - Deception Point.json [Content-Type=application/json]...
# Copying file://json/json_classical/497_Magic Inspiration.json [Content-Type=application/json]...
# Copying file://json/json_classical/181_The Blade_Main.json [Content-Type=application/json]...
# Copying file://json/json_classical/211_Paths Crossed, Lessons Learned.json [Content-Type=application/json]...
# Copying file://json/json_classical/452_Sentimental Action.json [Content-Type=application/json]...
# Copying file://json/json_classical/216_fall asleep  [Piano Music].json [Content-Type=application/json]...
# Copying file://json/json_classical/45_Peaceful Piano Background Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/270_Adventure Intro.json [Content-Type=application/json]...
# Copying file://json/json_classical/291_Help - Motivational Adventure Epic Action Cinematic Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/35_Da Vinci_Long.json [Content-Type=application/json]...
# Copying file://json/json_classical/449_Background music for short video vlog. Funny light accompanying.json [Content-Type=application/json]...
# Copying file://json/json_classical/106_mia & sebastian x je te laisserai des mots.json [Content-Type=application/json]...
# Copying file://json/json_classical/276_Piano Không Lời Văn Phòng Công Ty - Travel Vlog, Du Lịch, Youtuber.json [Content-Type=application/json]...
# Copying file://json/json_classical/121_Slow Piano and Rain.json [Content-Type=application/json]...
# Copying file://json/json_classical/119_Loneliness_Medium 1.json [Content-Type=application/json]...
# Copying file://json/json_classical/192_DIM News Flash - 5.json [Content-Type=application/json]...
# Copying file://json/json_classical/27_Moonlight Echoes.json [Content-Type=application/json]...
# Copying file://json/json_classical/381_Learn To Fly.json [Content-Type=application/json]...
# Copying file://json/json_classical/482_Ominous Tension.json [Content-Type=application/json]...
# Copying file://json/json_classical/412_Epical Cinematic.json [Content-Type=application/json]...
# Copying file://json/json_classical/462_Piano Sleep Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/152_Uplifting Life.json [Content-Type=application/json]...
# Copying file://json/json_classical/312_Legacy of Handel. Passacaglia Background music for video vlog 1 minute.json [Content-Type=application/json]...
# Copying file://json/json_classical/63_Wings of Freedom (No Copyright Motivational Music).json [Content-Type=application/json]...
# Copying file://json/json_classical/390_Wedding love Story.json [Content-Type=application/json]...
# Copying file://json/json_classical/77_moonlit night - relaxing piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/156_Desire for Freedom.json [Content-Type=application/json]...
# Copying file://json/json_classical/158_Meeting the Stars. Cinematic background music for short video 1 minute.json [Content-Type=application/json]...
# Copying file://json/json_classical/463_Epic Cinematic Intro_Medium 1.json [Content-Type=application/json]...
# Copying file://json/json_classical/25_Beautiful Things - piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/122_Positive spring day. Orchestral hip-hop ver Background music for video.json [Content-Type=application/json]...
# Copying file://json/json_classical/423_꿈의 멜로디.json [Content-Type=application/json]...
# Copying file://json/json_classical/318_Worship Piano Instrumental Peaceful Prayer Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/193_Epic Cinematic Drama_54sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/499_Tension.json [Content-Type=application/json]...
# Copying file://json/json_classical/84_Xoa Dịu Nỗi Lòng - Piano BGM.json [Content-Type=application/json]...
# Copying file://json/json_classical/289_Revival of Chopin Waltz. Hip-Hop version. Background piano music.json [Content-Type=application/json]...
# Copying file://json/json_classical/118_Epic Emotional_Medium 1.json [Content-Type=application/json]...
# Copying file://json/json_classical/393_Dreamtime 2.json [Content-Type=application/json]...
# Copying file://json/json_classical/96_Epic Emotional_Medium 2.json [Content-Type=application/json]...
# Copying file://json/json_classical/269_Clockwork Chaos (Dark Trailer Intro).json [Content-Type=application/json]...
# Copying file://json/json_classical/1_Inspiring Cinematic Ambient.json [Content-Type=application/json]...
# Copying file://json/json_classical/65_Tears.json [Content-Type=application/json]...
# Copying file://json/json_classical/380_Skyline.json [Content-Type=application/json]...
# Copying file://json/json_classical/250_Timeless Sonata.json [Content-Type=application/json]...
# Copying file://json/json_classical/385_Dòng Sông Trôi Qua Đi Làm Sao Tắm Lại Được - Nhạc Nền Video.json [Content-Type=application/json]...
# Copying file://json/json_classical/132_Militant Amelia. Epic drama orchestra background music for video 25sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/481_Magic Christmas_60sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/191_Whispers of the Desert Wind.json [Content-Type=application/json]...
# Copying file://json/json_classical/377_The Adventures of Mr. Hardy_30sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/151_Dramatic Atmosphere with Piano and Violin.json [Content-Type=application/json]...
# Copying file://json/json_classical/273_Relaxing Piano Music - Nhạc Nền Video.json [Content-Type=application/json]...
# Copying file://json/json_classical/71_Militant Amelia. Orchestral hip-hop background music for video vlog.json [Content-Type=application/json]...
# Copying file://json/json_classical/200_Heartbreaking (Emotional) Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/163_Militant Amelia. Cinematic orchestral background music for video 60sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/430_Peaceful Ripples.json [Content-Type=application/json]...
# Copying file://json/json_classical/454_Ancient Legend.json [Content-Type=application/json]...
# Copying file://json/json_classical/457_Illuminati - weird piano meme.json [Content-Type=application/json]...
# Copying file://json/json_classical/75_Field Grass.json [Content-Type=application/json]...
# Copying file://json/json_classical/373_Cinematic Epic Trailer Background Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/443_Beethoven - Moonlight Sonata (1. Movement) - Op. 27, Nr. 2.json [Content-Type=application/json]...
# Copying file://json/json_classical/110_Beautiful Piano Tracks for Studying, Relaxation, Sleep - Piano BGM.json [Content-Type=application/json]...
# Copying file://json/json_classical/468_Inspiring Landscape.json [Content-Type=application/json]...
# Copying file://json/json_classical/285_Không Gian Văn Phòng Sáng Tạo Năng Động - Nhạc Nền Video.json [Content-Type=application/json]...
# Copying file://json/json_classical/316_embrace the journey, not the destination.json [Content-Type=application/json]...
# Copying file://json/json_classical/120_Ambient Inspiring Piano Music (Beautiful).json [Content-Type=application/json]...
# Copying file://json/json_classical/49_Emotional Inspiring Epic Trailer.json [Content-Type=application/json]...
# Copying file://json/json_classical/308_Background epic piano music for short video vlog, advertising 24 sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/244_Peaceful Sleep.json [Content-Type=application/json]...
# Copying file://json/json_classical/13_Eco Technology.json [Content-Type=application/json]...
# Copying file://json/json_classical/428_Piano and Nature Sounds.json [Content-Type=application/json]...
# Copying file://json/json_classical/162_Winter Legacy. The Four Seasons Antonio Vivaldi Hip-Hop version 39 sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/91_Motivational Epic Advertising.json [Content-Type=application/json]...
# Copying file://json/json_classical/101_Cinematic Background Inspirational.json [Content-Type=application/json]...
# Copying file://json/json_classical/32_Solas x Interstellar (Piano).json [Content-Type=application/json]...
# Copying file://json/json_classical/56_Warrior_30sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/188_Da Vinci_59sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/131_Sad Waltz (Piano).json [Content-Type=application/json]...
# Copying file://json/json_classical/54_For When It Rains.json [Content-Type=application/json]...
# Copying file://json/json_classical/2_Risk.json [Content-Type=application/json]...
# Copying file://json/json_classical/400_Unfailing Love.json [Content-Type=application/json]...
# Copying file://json/json_classical/76_golden hour- Beautiful Piano Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/357_Una Luna - relaxing piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/22_Loves Serenade.json [Content-Type=application/json]...
# Copying file://json/json_classical/55_Loneliness_Outro.json [Content-Type=application/json]...
# Copying file://json/json_classical/85_Lặng Nhìn Dòng Nước Cuốn Trôi Theo Bao Nỗi Ưu Phiền - Piano BGM.json [Content-Type=application/json]...
# Copying file://json/json_classical/493_Endless World.json [Content-Type=application/json]...
# Copying file://json/json_classical/383_Nỗi Buồn Tan Biến - Piano Cafe.json [Content-Type=application/json]...
# Copying file://json/json_classical/438_Deep Cinematic Ballad_36sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/444_Blessed (Main).json [Content-Type=application/json]...
# Copying file://json/json_classical/135_Wake Me Up.json [Content-Type=application/json]...
# Copying file://json/json_classical/180_TIME.json [Content-Type=application/json]...
# Copying file://json/json_classical/386_Lời Yêu Thương Ấm Áp - Travel Vlog, Du Lịch, Youtuber.json [Content-Type=application/json]...
# Copying file://json/json_classical/24_Epic Hollywood Trailer.json [Content-Type=application/json]...
# Copying file://json/json_classical/460_Emotional Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/179_Romantic Love Piano Song - Until I Found You.json [Content-Type=application/json]...
# Copying file://json/json_classical/141_Beautiful Relaxing Music for Stress Relief - Piano Cafe.json [Content-Type=application/json]...
# Copying file://json/json_classical/314_Heroic Quest.json [Content-Type=application/json]...
# Copying file://json/json_classical/259_The Art of Letting Go.json [Content-Type=application/json]...
# Copying file://json/json_classical/235_DIM Meditation 396 Hz.json [Content-Type=application/json]...
# Copying file://json/json_classical/303_Positive short background music for video. Positive spring day 1 min.json [Content-Type=application/json]...
# Copying file://json/json_classical/134_Inspiring Epic Motivation Cinematic Trailer.json [Content-Type=application/json]...
# Copying file://json/json_classical/262_Warrior_52sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/265_Taking Flight.json [Content-Type=application/json]...
# Copying file://json/json_classical/376_Europe Travel.json [Content-Type=application/json]...
# Copying file://json/json_classical/338_Heroes of the Realm of Camelot.json [Content-Type=application/json]...
# Copying file://json/json_classical/184_We Confidently Go To Victory.json [Content-Type=application/json]...
# Copying file://json/json_classical/237_Romantic piano background music for short video vlog, blog 1 minute.json [Content-Type=application/json]...
# Copying file://json/json_classical/249_Serpents of War.json [Content-Type=application/json]...
# Copying file://json/json_classical/411_Human Greed.json [Content-Type=application/json]...
# Copying file://json/json_classical/282_Mặt Hồ Phẳng Lặng Phản Chiếu Cảnh Trời Mây - Piano Cafe.json [Content-Type=application/json]...
# Copying file://json/json_classical/347_Reborn (Epic Movie Theme) INSTRUMENTAL.json [Content-Type=application/json]...
# Copying file://json/json_classical/99_Invisible - Piano Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/324_Sweet Dreams.json [Content-Type=application/json]...
# Copying file://json/json_classical/247_Alive- Emotional Minimal Ambient Piano Inspirational.json [Content-Type=application/json]...
# Copying file://json/json_classical/88_Bỏ Thành Thị Về Quê Lập Nghiệp.json [Content-Type=application/json]...
# Copying file://json/json_classical/208_Midnight.json [Content-Type=application/json]...
# Copying file://json/json_classical/64_Warrior_Long.json [Content-Type=application/json]...
# Copying file://json/json_classical/261_Eternal Ascent.json [Content-Type=application/json]...
# Copying file://json/json_classical/210_Emotional Cinematic_Medium 1.json [Content-Type=application/json]...
# Copying file://json/json_classical/214_Ambient Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/224_Epicaly - Short.json [Content-Type=application/json]...
# Copying file://json/json_classical/43_Live To Love.json [Content-Type=application/json]...
# Copying file://json/json_classical/331_Strategist #1.json [Content-Type=application/json]...
# Copying file://json/json_classical/126_Epic Emotional_59sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/206_THE WAY HOME.json [Content-Type=application/json]...
# Copying file://json/json_classical/302_Emotional Cinematic_Medium 2.json [Content-Type=application/json]...
# Copying file://json/json_classical/165_Endless Elegance.json [Content-Type=application/json]...
# Copying file://json/json_classical/409_Note To Say Good Bye.json [Content-Type=application/json]...
# Copying file://json/json_classical/73_This Is Epic.json [Content-Type=application/json]...
# Copying file://json/json_classical/169_Da Vinci_Medium 1.json [Content-Type=application/json]...
# Copying file://json/json_classical/9_Waterfall.json [Content-Type=application/json]...
# Copying file://json/json_classical/433_Vivaldi - Four Seasons _Winter_ - RV 297 - Arr. for Strings.json [Content-Type=application/json]...
# Copying file://json/json_classical/353_Creative Rise_57sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/487_The HIdden Diamonds.json [Content-Type=application/json]...
# Copying file://json/json_classical/109_Exciting Day (Inspiring Piano).json [Content-Type=application/json]...
# Copying file://json/json_classical/387_The other side - Beautiful Piano Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/304_reading - soft piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/242_Ambient Inspiration.json [Content-Type=application/json]...
# Copying file://json/json_classical/340_Hopeful Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/413_Watching the Stars Background music for video.json [Content-Type=application/json]...
# Copying file://json/json_classical/351_Eclipse (Beautiful Piano).json [Content-Type=application/json]...
# Copying file://json/json_classical/167_Background epic piano music for short video vlog, advertising 1 minute.json [Content-Type=application/json]...
# Copying file://json/json_classical/257_Love Of My Life.json [Content-Type=application/json]...
# Copying file://json/json_classical/108_One Last Time.json [Content-Type=application/json]...
# Copying file://json/json_classical/404_Cold Cinematic Landscape.json [Content-Type=application/json]...
# Copying file://json/json_classical/486_Action Intro Trailer.json [Content-Type=application/json]...
# Copying file://json/json_classical/315_Emotional Cinematic_50sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/185_The Epical Trailer.json [Content-Type=application/json]...
# Copying file://json/json_classical/328_My Love_Short.json [Content-Type=application/json]...
# Copying file://json/json_classical/301_Viola (Cinematic Emotional Storytelling).json [Content-Type=application/json]...
# Copying file://json/json_classical/140_Góc Làm Việc Chill - Relaxing Piano For Youtube Video.json [Content-Type=application/json]...
# Copying file://json/json_classical/114_Softer Love - beautiful piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/148_Tràn Đầy Năng Lượng Cho Ngày Mới - Piano Cafe.json [Content-Type=application/json]...
# Copying file://json/json_classical/498_Cinematic Dark Trailer_41sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/354_Thinking Piano Music Ambience.json [Content-Type=application/json]...
# Copying file://json/json_classical/321_The Flashback_60sec 1.json [Content-Type=application/json]...
# Copying file://json/json_classical/480_Silver Sparkles.json [Content-Type=application/json]...
# Copying file://json/json_classical/230_Soft Inspirational Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/42_Remember (Emotional Piano) INSTRUMENTAL.json [Content-Type=application/json]...
# Copying file://json/json_classical/58_Dòng Sông Phẳng Lặng Như Tờ - Relaxing Piano For Youtube Video.json [Content-Type=application/json]...
# Copying file://json/json_classical/256_Soft ambient.json [Content-Type=application/json]...
# Copying file://json/json_classical/342_Cinematic Victory Theme.json [Content-Type=application/json]...
# Copying file://json/json_classical/190_Nature.json [Content-Type=application/json]...
# Copying file://json/json_classical/251_Legacy of Handel. Legendary Passacaglia. Background music for videos.json [Content-Type=application/json]...
# Copying file://json/json_classical/305_Cinematic Melody (Main).json [Content-Type=application/json]...
# Copying file://json/json_classical/14_Cinematic Time Lapse.json [Content-Type=application/json]...
# Copying file://json/json_classical/476_Daybreak Melody.json [Content-Type=application/json]...
# Copying file://json/json_classical/333_Serenity (Inspiring and Calm Piano Background).json [Content-Type=application/json]...
# Copying file://json/json_classical/123_Fight.json [Content-Type=application/json]...
# Copying file://json/json_classical/365_Dramatic background orchestral hip hop music for vlog video. G Minor.json [Content-Type=application/json]...
# Copying file://json/json_classical/488_Magic Christmas_24sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/406_Deep Cinematic Ballad_42sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/233_Background epic piano music for short video vlog, advertising 23 sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/292_Fall - sad autumn piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/62_Mariage d'Amour - Beautiful Ambient Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/128_Verdant Vivaldi.json [Content-Type=application/json]...
# Copying file://json/json_classical/245_Piano Sad Background Music For Videos.json [Content-Type=application/json]...
# Copying file://json/json_classical/232_Epic Cinematic Drama_Medium.json [Content-Type=application/json]...
# Copying file://json/json_classical/187_Take A Day Trip.json [Content-Type=application/json]...
# Copying file://json/json_classical/442_Forget.json [Content-Type=application/json]...
# Copying file://json/json_classical/51_Honor and Sword (Main).json [Content-Type=application/json]...
# Copying file://json/json_classical/363_Fall of Whiterun.json [Content-Type=application/json]...
# Copying file://json/json_classical/145_Tập Trung Vào Công Việc - Piano Relaxing (Instagram Music).json [Content-Type=application/json]...
# Copying file://json/json_classical/129_November Wind.json [Content-Type=application/json]...
# Copying file://json/json_classical/349_Cinematic Dark Trailer_43sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/116_Slow Motion.json [Content-Type=application/json]...
# Copying file://json/json_classical/450_Pictures of Memories.json [Content-Type=application/json]...
# Copying file://json/json_classical/367_Emotional Piano Sad Background Music For Videos.json [Content-Type=application/json]...
# Copying file://json/json_classical/10_Reflected Light.json [Content-Type=application/json]...
# Copying file://json/json_classical/399_Winds of Peace.json [Content-Type=application/json]...
# Copying file://json/json_classical/204_DIM News Flash - 5.json [Content-Type=application/json]...
# Copying file://json/json_classical/448_The Epic Intro Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/275_Thả Hồn Trôi Theo Dòng Nước Thênh Thang - Piano BGM.json [Content-Type=application/json]...
# Copying file://json/json_classical/369_First Petal.json [Content-Type=application/json]...
# Copying file://json/json_classical/226_Relaxing, Sad Piano Music - Lost Dreams.json [Content-Type=application/json]...
# Copying file://json/json_classical/236_Always With Me, Always With You (Piano Long).json [Content-Type=application/json]...
# Copying file://json/json_classical/420_Sad Emotional and Dramatic Piano.json [Content-Type=application/json]...
# Copying file://json/json_classical/229_Cinematic Adventure _ Alive.json [Content-Type=application/json]...
# Copying file://json/json_classical/392_Bach - Violin Concerto in A minor - 3. Movement - BWV 1041.json [Content-Type=application/json]...
# Copying file://json/json_classical/61_Epic emotinal inspirational.json [Content-Type=application/json]...
# Copying file://json/json_classical/298_No Idea - Soft Piano Music.json [Content-Type=application/json]...
# Copying file://json/json_classical/437_The Adventures of Mr. Hardy_60sec.json [Content-Type=application/json]...
# Copying file://json/json_classical/238_Epic music. Short background music for video vlogs, promo 1 minute.json [Content-Type=application/json]...
# Copying file://json/json_classical/146_Tiếng Piano Kích Hoạt Sự Sáng Tạo - Travel Vlog, Du Lịch, Youtuber.json [Content-Type=application/json]...
# Copying file://json/json_classical/161_Heroes among us. Dramatic background music for video vlog 1 minute.json [Content-Type=application/json]...
# Copying file://json/json_classical/4_Majestic Voyage.json [Content-Type=application/json]...
# Copying file://json/json_classical/248_Light, cheerful short background music for video vlogs. Funny hip hop.json [Content-Type=application/json]...
# Copying file://json/json_classical/159_Medieval Fantasy.json [Content-Type=application/json]...
# Copying file://json/json_classical/418_Victory's Anthem War.json [Content-Type=application/json]...
# Copying file://json/json_classical/281_Calming Piano Music  For Sleep - Relaxing Piano For Youtube Video.json [Content-Type=application/json]...
# Copying file://json/json_classical/95_Emotional Thoughtful Piano (Thinking In Silence).json [Content-Type=application/json]...
# Copying file://json/json_classical/310_Epic Cinematic Drama_60sec.json [Content-Type=application/json]...
# ...
# Copying file://audio_files/by_genre/498_classical_audiofiles/9_waterfall-140894.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/469_epic-music-background-instrumental-for-video-dramatic-hip-hop-beat-176723.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/139_dialogues-with-the-past-225668.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/211_paths-crossed-lessons-learned-225617.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/353_creative-rise_57sec-178303.mp3 [Content-Type=audio/mpeg]...
# INFO 0814 23:53:12.712658 retry_util.py] Retrying request, attempt #1...3
# Copying file://audio_files/by_genre/498_classical_audiofiles/121_slow-piano-and-rain-220167.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/51_honor-and-sword-main-11222.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/238_epic-music-short-background-music-for-video-vlogs-promo-1-minute-194801.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/354_thinking-piano-music-ambience-225272.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/200_heartbreaking-emotional-piano-215740.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/356_time-pt3-221116.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/481_magic-christmas_60sec-177542.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/3_science-documentary-169621.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/19_winter-legacy-the-four-seasons-hip-hop-version-background-music-201042.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/12_relaxing-145038.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/386_loi-yeu-thuong-am-ap-travel-vlog-du-lich-youtuber-227812.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/373_cinematic-epic-trailer-background-music-123922.mp3 [Content-Type=audio/mpeg]...
# INFO 0814 23:53:31.860367 retry_util.py] Retrying request, attempt #1...9
# Copying file://audio_files/by_genre/498_classical_audiofiles/364_piano-music-lose-control-219964.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/471_documentary-background-119940.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/231_romantic-love-piano-150084.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/482_ominous-tension-157906.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/209_the-shield-111353.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/476_daybreak-melody-224635.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/48_the-epic-trailer-12955.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/86_khong-gian-lam-viec-li-tuong-piano-relaxing-instagram-music-227827.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/132_militant-amelia-epic-drama-orchestra-background-music-for-video-25sec-205318.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/155_beethoven-concert-nr3-relaxing-classical-piano-216328.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/318_worship-piano-instrumental-peaceful-prayer-music-223373.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/363_fall-of-whiterun-200147.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/1_inspiring-cinematic-ambient-116199.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/129_november-wind-224282.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/208_midnight-123895.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/415_background-music-for-video-21-sec-legacy-of-chopin-nocturne-op9-no2-189904.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/239_i-giorni-205574.mp3 [Content-Type=audio/mpeg]...
# INFO 0814 23:53:45.074458 retry_util.py] Retrying request, attempt #1...7
# Copying file://audio_files/by_genre/498_classical_audiofiles/265_taking-flight-205965.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/109_exciting-day-inspiring-piano-176148.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/96_epic-emotional_medium-2-197087.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/232_epic-cinematic-drama_medium-187363.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/179_romantic-love-piano-song-until-i-found-you-218336.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/243_apocalypse_v3_59sec-178285.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/277_peaceful-piano-music-piano-bgm-227820.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/359_beautiful-trip-142481.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/193_epic-cinematic-drama_54sec-187364.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/2_risk-136788.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/371_the-first-days-of-spring-188392.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/409_note-to-say-good-bye-221567.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/444_blessed-main-120698.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/317_peaceful-cinematic-141736.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/112_big-dreams-small-steps-225666.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/213_sad-moment-sad-and-melancholy-piano-background-music-124488.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/278_tu-duy-sang-tao-tai-van-phong-cong-ty-nhac-nen-video-227824.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/422_crazy-mind-piano-music-216335.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/113_cinematic-action-intro-210366.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/283_augustyn-engty-moonlight-royalty-free-music-227203.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/99_invisible-piano-music-201838.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/382_contemporary-classical-quotserenityx27s-sonata-iiquot-223893.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/497_magic-inspiration-201208.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/196_virtuoso-210063.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/328_my-love_short-177579.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/146_tieng-piano-kich-hoat-su-sang-tao-travel-vlog-du-lich-youtuber-227829.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/436_epic-background-piano-music-for-short-video-vlog-advertising-1-minute-182222.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/459_the-calm-ocean-212561.mp3 [Content-Type=audio/mpeg]...
# INFO 0814 23:54:40.500124 retry_util.py] Retrying request, attempt #1...4
# Copying file://audio_files/by_genre/498_classical_audiofiles/233_background-epic-piano-music-for-short-video-vlog-advertising-23-sec-189905.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/29_sad-waltz-mia-and-sebastians-theme-piano-225723.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/40_cinematic-dramatic-11120.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/215_inspiring-cinematic-190553.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/335_cinematic-dark-trailer-130489.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/402_lovely-brunch-200502.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/102_lost-dreams-inspiring-cinematic-ambient-208164.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/461_cinematic-motivational-136831.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/280_anh-sang-nho-trong-bong-em-relaxing-piano-for-youtube-video-227809.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/188_da-vinci_59sec-202368.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/79_heroes-among-us-cinematic-orchestral-background-music-for-video-60sec-203756.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/460_emotional-piano-141472.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/23_beautiful-piano-music-felt-piano-now-we-are-free-219961.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/321_the-flashback_60sec-1-174161.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/218_climax-epic-sad-piano-song-200132.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/166_touch-and-sound-113676.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/297_beautiful-piano-115480.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/500_two-silly-monkeys-174980.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/495_the-power-within-223332.mp3 [Content-Type=audio/mpeg]...
# INFO 0814 23:55:04.551268 retry_util.py] Retrying request, attempt #1...1
# INFO 0814 23:55:05.152595 retry_util.py] Retrying request, attempt #1...2
# Copying file://audio_files/by_genre/498_classical_audiofiles/101_cinematic-background-inspirational-150013.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/299_lost-in-the-enchanted-woods-191319.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/105_alice-in-dark-wonderland-123894.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/24_epic-hollywood-trailer-9489.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/456_fearsome-tipsy-pirates-pirates-epic-trailer-200229.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/315_emotional-cinematic_50sec-186759.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/140_goc-lam-viec-chill-relaxing-piano-for-youtube-video-227828.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/54_for-when-it-rains-112785.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/117_one-love-story-orchestral-hip-hop-version-background-music-for-video-194766.mp3 [Content-Type=audio/mpeg]...
# INFO 0814 23:55:21.566888 retry_util.py] Retrying request, attempt #2...8
# Copying file://audio_files/by_genre/498_classical_audiofiles/464_journeys-of-the-soul-225655.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/235_dim-meditation-396-hz-227138.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/324_sweet-dreams-150475.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/370_inspirational-sentimental-moments-204865.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/225_background-music-for-short-video-vlog-promo-era-of-cyborgs-1-minute-199952.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/110_beautiful-piano-tracks-for-studying-relaxation-sleep-piano-bgm-227821.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/214_ambient-piano-215975.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/446_middle-ages-147373.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/241_arcade-piano-218340.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/404_cold-cinematic-landscape-116954.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/47_relaxing-piano-201831.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/126_epic-emotional_59sec-197083.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/357_una-luna-relaxing-piano-216337.mp3 [Content-Type=audio/mpeg]...
# INFO 0814 23:55:34.796312 retry_util.py] Retrying request, attempt #1...7
# Copying file://audio_files/by_genre/498_classical_audiofiles/366_busy-bees-158999.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/10_reflected-light-147979.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/133_da-vinci_short-202370.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/348_epic-background-orchestral-instrumental-music-for-short-videos-26-sec-180908.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/114_softer-love-beautiful-piano-216336.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/107_militant-amelia-dramatic-background-music-for-video-vlog-1-minute-205321.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/447_the-wrath-of-the-samurai-226908.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/498_classical_audiofiles/204_dim-news-flash-5-227133.mp3 [Content-Type=audio/mpeg]...
# INFO 0814 23:56:03.212543 retry_util.py] Retrying request, attempt #1...1
# INFO 0814 23:56:03.214303 retry_util.py] Retrying request, attempt #1...
# INFO 0814 23:56:03.300423 retry_util.py] Retrying request, attempt #1...1
# | [996/996 files][  4.5 GiB/  4.5 GiB] 100% Done   2.1 MiB/s ETA 00:00:00
# Operation completed over 996 objects/4.5 GiB.

# %% [markdown]
# ### 3.3. Verify if uploading operation is successful

# %%
from google.cloud import storage
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv(dotenv_path='notebooks/dataset for fine-tuning/.env')

# Access the variables from the .env file
bucket_name = os.getenv('bucket_name')
folder_name = os.getenv('folder_name')

def verify_upload(bucket_name, folder_name, source_folders):
    """Verifies if the specified folder and its subfolders exist in the given GCS bucket."""

    # Get the path to your service account credentials JSON file from the environment variable
    credentials_path = os.getenv('gcp_api_json_path')

    # Explicitly create the storage client using the service account credentials
    storage_client = storage.Client.from_service_account_json(credentials_path)

    bucket = storage_client.bucket(bucket_name)

    # Check if the main folder exists
    blobs = list(bucket.list_blobs(prefix=folder_name + '/'))
    if not blobs:
        print(f"Upload failed or incomplete. Main folder '{folder_name}' not found in bucket '{bucket_name}'.")
        return  # Stop further checks if the main folder is missing

    # Check for the existence of each subfolder within the main folder
    for source_folder in source_folders:
        blobs = list(bucket.list_blobs(prefix=f"{folder_name}/{source_folder}/"))

        if blobs:
            print(f"Upload successful! Subfolder '{source_folder}' and its contents found in bucket '{bucket_name}' under '{folder_name}'.")
            # (Optional) You can iterate through 'blobs' to list individual files if needed
            # for blob in blobs:
            #   print(f"  - {blob.name}")
        else:
            print(f"Upload failed or incomplete. Subfolder '{source_folder}' not found in bucket '{bucket_name}' under '{folder_name}'.")

# List of source folders you want to upload
source_folders = [
    'json',
    'dataframes/checked',
    'dataframes/filtered_by_genre',
    'audio_files/by_genre',
    'audio_files/final_backup',
]

verify_upload(bucket_name, folder_name, source_folders)
# Out:
# Upload successful! Subfolder 'json' and its contents found in bucket 'sam-dataset' under '498_classical_files_2024-08-14_23-31-04'.
# Upload successful! Subfolder 'dataframes/checked' and its contents found in bucket 'sam-dataset' under '498_classical_files_2024-08-14_23-31-04'.
# Upload successful! Subfolder 'dataframes/filtered_by_genre' and its contents found in bucket 'sam-dataset' under '498_classical_files_2024-08-14_23-31-04'.
# Upload successful! Subfolder 'audio_files/by_genre' and its contents found in bucket 'sam-dataset' under '498_classical_files_2024-08-14_23-31-04'.
# Upload successful! Subfolder 'audio_files/final_backup' and its contents found in bucket 'sam-dataset' under '498_classical_files_2024-08-14_23-31-04'.

# %% [markdown]
# ## 4. Delete final operation folders

# %%
# %%bash
#
# # Delete the folders and their contents
# rm -rf audio_files/final_backup audio_files/by_genre json/*

# %% [markdown]
# # All done, bravo ! (by Arthur Cornélio, 12th August 2024)
