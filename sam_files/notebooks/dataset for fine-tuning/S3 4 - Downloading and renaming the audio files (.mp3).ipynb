# %% [markdown]
# # 4 - Downloading and renaming the audio files (.mp3)

# %% [markdown]
# ## 1. Open genre dataframe (.csv) in a table editor
#   - Open your .csv file in a Google Sheet or similar
#   - ⚠️ **Put a number '1' for dowloaded audio files, in `downloaded?` column**

# %% [markdown]
# ## 2. Create folders for processing downloaded audio files

# %% [markdown]
# ### a) Load .env variables

# %%
# load .env variables
from dotenv import load_dotenv
import os

load_dotenv()

GITHUB_PROFILE_NAME = os.getenv('GITHUB_PROFILE_NAME')
genre = os.getenv('genre')

# %%
genre
# Out:
# 'classical'

# %% [markdown]
# ### b) Create processing folders
#   - `vo_{github-profile}`: where the final files will be placed
#   - `transition_{github-profile}` : where every renaming processing will be done
#   - `backup_{github-profile}` : put files from transition folder to here every 20 processed file

# %%
# create folders
import os
from pathlib import Path
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

def create_folders():
    """
    Creates three folders (v0, transition, backup) within the 'audio_files' directory
    relative to the user's home directory and GitHub profile name.
    """

    # Automatically get the user's home directory
    home_dir = os.path.expanduser('~')

    # Capture the GitHub profile name from the environment variable
    github_profile_name = os.getenv('GITHUB_PROFILE_NAME')

    # Construct the base path for the audio_files directory
    base_path = os.path.join(home_dir, f'code/{github_profile_name}/stable-audio-tools-sam/sam_files/audio_files/_processing')

    # Define the folder names to be created
    v0 = f"v0_{github_profile_name}"
    transition = f"transition_{github_profile_name}"
    backup = f"backup_{github_profile_name}"
    folders = [v0, transition, backup]

    # Create the directories
    for folder in folders:
        folder_path = os.path.join(base_path, folder)

        # Check if the folder already exists
        if not os.path.exists(folder_path):
            # Create the folder if it doesn't exist
            os.makedirs(folder_path)
            print(f"Created folder: {folder_path}")
        else:
            print(f"Folder already exists: {folder_path}")

# Run the function to create the folders
create_folders()
# Out:
# Created folder: /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files/audio_files/_processing/v0_arthurcornelio88
# Created folder: /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files/audio_files/_processing/transition_arthurcornelio88
# Created folder: /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files/audio_files/_processing/backup_arthurcornelio88

# %% [markdown]
# ## 3. Download audio files
#   - Put them in audio_files/___processing/transition etc
#   - We recommend that you download 10 or 20 files at a time.
#   - You will alternate between step 3 and 4 until you finish the download of all files. Good luck !
#   - ⚠️ If you can't download a file, you need to erase its .JSON file

# %% [markdown]
# ## 4. Rename files

# %% [markdown]
# ### 4.1. Run the script "rename_files_by_url_key.py"

# %% [markdown]
# - ⚠️ Set the path just once !
# - It needs to be ../stable-audio-tools-sam/sam_files
# - If don't, restart the notebook and run this cell below again

# %%
# set path
# %cd ..
# %cd ..
# Out:
# /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files/notebooks
# /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files

# %%
# rename_files_by_dataframe

# !python scripts/rename_files_by_url_key.py \
    audio_files/_processing/transition_{GITHUB_PROFILE_NAME}/ \
    dataframes/filtered_by_genre/500_{genre}_tracks.csv

# %% [markdown]
# ⚠️ OPTIONAL - You'll need to adjust the index after the first renaming turn :
#   - --start_index 20 , for files from 20 to 40

# %%
# OPTIONAL - rename_files.py

# !python scripts/rename_files.py \
    audio_files/_processing/transition_{GITHUB_PROFILE_NAME}/ \
    # --start_index 1

# %% [markdown]
# - If you need to rename an existing file, use the script "rename_and_adjust.py"

# %%
# OPTIONAL - simple renaming and adjusting neighbors files
## !python rename_and_adjust.py <folder_path> <target_file_name> <target_index> [--add] [--undo]

# !python scripts/rename_and_adjust.py \
    audio_files/_processing/transition_{GITHUB_PROFILE_NAME} \
    1_audio1test.mp3 \
    8

# %% [markdown]
# - If you need to add a new file, use the script "rename_and_adjust.py" with the flag --add

# %%
# OPTIONAL adding one new file
# !python scripts/rename_and_adjust.py \
    audio_files/_processing/transition_{GITHUB_PROFILE_NAME} \
    audio10test.mp3 \
    8 \
    --add

# %% [markdown]
#   - If you need to undo the last modification

# %%
# OPTIONAL to undo the renaming
# !python \
    scripts/rename_and_adjust.py \
   audio_files/_processing/transition_{GITHUB_PROFILE_NAME} \
    "placeholder" \
    0 \
    --undo
# Out:
# Renamed '499_499_own-conversation-elevator-191517.mp3' to '498_499_own-conversation-elevator-191517.mp3' (undo)

# %% [markdown]
#   - Or if you want to start from zero and erase the prefixes, use "remove_prefixes.py"

# %%
# OPTIONAL - remove prefixes
# !python scripts/remove_prefixes.py audio_files/_processing/transition_{GITHUB_PROFILE_NAME}

# %% [markdown]
# ### 4.2. Move files
#
# - Move renamed files (in /transition) to /v0_yourname

# %%
# move renamed files (in /transition) to /v0_yourname

# !mv audio_files/_processing/transition_{GITHUB_PROFILE_NAME}/* audio_files/_processing/v0_{GITHUB_PROFILE_NAME}/

# %% [markdown]
# ⚠️ If you need to undo the last operation

# %%
# OPTIONAL - undo last operation
#
# !mv audio_files/_processing/v0_{GITHUB_PROFILE_NAME}/* audio_files/_processing/transition_{GITHUB_PROFILE_NAME}/

# %% [markdown]
# ### 4.3 Rename JSON files

# %%
# rename JSON file according to audiofiles

# !python scripts/rename_json_files.py \
    json/json_{genre} \
    audio_files/_processing/v0_{GITHUB_PROFILE_NAME}
# Out:
# Renamed 230_Soft Inspirational Piano.json to 230_soft-inspirational-piano-153643.json
# Renamed 291_Help - Motivational Adventure Epic Action Cinematic Music.json to 291_help-motivational-adventure-epic-action-cinematic-music-218827.json
# Renamed 212_The Flashback_60sec 2.json to 212_the-flashback_60sec-2-174160.json
# Renamed 120_Ambient Inspiring Piano Music (Beautiful).json to 120_ambient-inspiring-piano-music-beautiful-214863.json
# Renamed 440_moon weasel - Piano Music.json to 440_moon-weasel-piano-music-221778.json
# Renamed 350_Legacy of Chopin. Nocturne No. 20 Hip-Hop version. Background music.json to 350_legacy-of-chopin-nocturne-no-20-hip-hop-version-background-music-180907.json
# Renamed 376_Europe Travel.json to 376_europe-travel-119948.json
# Renamed 271_Dưới Ánh Trăng Yêu Thương - Nhạc Nền Video.json to 271_duoi-anh-trang-yeu-thuong-nhac-nen-video-227795.json
# Renamed 254_We wish you a Merry Christmas_60sec.json to 254_we-wish-you-a-merry-christmas_60sec-174155.json
# Renamed 399_Winds of Peace.json to 399_winds-of-peace-226183.json
# Renamed 41_Inspiring Emotional Uplifting Piano.json to 41_inspiring-emotional-uplifting-piano-112623.json
# Renamed 465_peace - piano song.json to 465_peace-piano-song-216338.json
# Renamed 205_rainy noon - Relaxing Uplifting Piano.json to 205_rainy-noon-relaxing-uplifting-piano-221782.json
# Renamed 264_Uplifting Fairy Tale.json to 264_uplifting-fairy-tale-150106.json
# Renamed 251_Legacy of Handel. Legendary Passacaglia. Background music for videos.json to 251_legacy-of-handel-legendary-passacaglia-background-music-for-videos-191898.json
# Renamed 170_Song From A Secret Garden (Sad Piano).json to 170_song-from-a-secret-garden-sad-piano-205576.json
# Renamed 11_Winning Elevation.json to 11_winning-elevation-111355.json
# Renamed 185_The Epical Trailer.json to 185_the-epical-trailer-158083.json
# Renamed 73_This Is Epic.json to 73_my-love-medium-177577.json
# Renamed 358_Dramatic Atmosphere with Piano and Violin (Short Version).json to 358_dramatic-atmosphere-with-piano-and-violin-short-version-199232.json
# Renamed 158_Meeting the Stars. Cinematic background music for short video 1 minute.json to 158_meeting-the-stars-cinematic-background-music-for-short-video-1-minute-197576.json
# Renamed 285_Không Gian Văn Phòng Sáng Tạo Năng Động - Nhạc Nền Video.json to 285_khong-gian-van-phong-sang-tao-nang-ong-nhac-nen-video-227823.json
# Renamed 65_Tears.json to 65_tears-223082.json
# Renamed 156_Desire for Freedom.json to 156_desire-for-freedom-124112.json
# Renamed 383_Nỗi Buồn Tan Biến - Piano Cafe.json to 383_noi-buon-tan-bien-piano-cafe-227810.json
# Renamed 20_Battlefield Elegy.json to 20_battlefield-elegy-201530.json
# Renamed 345_Inspiring Uplifting Cinematic Piano.json to 345_inspiring-uplifting-cinematic-piano-119523.json
# Renamed 42_Remember (Emotional Piano) INSTRUMENTAL.json to 42_remember-emotional-piano-instrumental-227308.json
# Renamed 498_Cinematic Dark Trailer_41sec.json to 498_cinematic-dark-trailer_41sec-178298.json
# Renamed 187_Take A Day Trip.json to 187_take-a-day-trip-222851.json
# Renamed 342_Cinematic Victory Theme.json to 342_cinematic-victory-theme-202139.json
# Renamed 393_Dreamtime 2.json to 393_dreamtime-2-222921.json
# Renamed 439_Idea 15.json to 439_idea-15-205573.json
# Renamed 194_Da Vinci_Medium 2.json to 194_da-vinci_medium-2-202371.json
# Renamed 89_Về Quê Nuôi Cá Trồng Rau An Nhàn.json to 89_ve-que-nuoi-ca-trong-rau-an-nhan-227834.json
# Renamed 244_Peaceful Sleep.json to 244_peaceful-sleep-188311.json
# Renamed 207_Epic Cinematic Intro_26sec.json to 207_epic-cinematic-intro_26sec-178310.json
# Renamed 286_Golden Sunset - Piano Music.json to 286_golden-sunset-piano-music-200136.json
# Renamed 413_Watching the Stars Background music for video.json to 413_watching-the-stars-background-music-for-video-8756.json
# Renamed 189_Warrior's Peace.json to 189_warriorx27s-peace-222483.json
# Renamed 396_A Thousand Times.json to 396_a-thousand-times-222455.json
# Renamed 52_Cute Creatures.json to 52_cute-creatures-150622.json
# Renamed 443_Beethoven - Moonlight Sonata (1. Movement) - Op. 27, Nr. 2.json to 443_beethoven-moonlight-sonata-1-movement-op-27-nr-2-180627.json
# Renamed 384_Chạm Vào Trái Tim Bằng Nốt Nhạc - Piano Cafe.json to 384_cham-vao-trai-tim-bang-not-nhac-piano-cafe-227798.json
# Renamed 419_Find Your Zen 2.json to 419_find-your-zen-2-222923.json
# Renamed 431_live long enough and become a villain.json to 431_live-long-enough-and-become-a-villain-225667.json
# Renamed 308_Background epic piano music for short video vlog, advertising 24 sec.json to 308_background-epic-piano-music-for-short-video-vlog-advertising-24-sec-193852.json
# Renamed 490_Sad Piano and Violin.json to 490_sad-piano-and-violin-200661.json
# Renamed 488_Magic Christmas_24sec.json to 488_magic-christmas_24sec-177540.json
# Renamed 290_Wedding Hopeful Cinematic Piano.json to 290_wedding-hopeful-cinematic-piano-150109.json
# Renamed 320_Loyalty To The Crown_40sec.json to 320_loyalty-to-the-crown_40sec-187373.json
# Renamed 163_Militant Amelia. Cinematic orchestral background music for video 60sec.json to 163_militant-amelia-cinematic-orchestral-background-music-for-video-60sec-205322.json
# Renamed 455_Calm and Peaceful.json to 455_calm-and-peaceful-115481.json
# Renamed 380_Skyline.json to 380_skyline-224239.json
# Renamed 346_Deep in the Dell.json to 346_deep-in-the-dell-126916.json
# Renamed 103_let me go - sad piano.json to 103_let-me-go-sad-piano-218347.json
# Renamed 111_Out of Time.json to 111_out-of-time-15474.json
# Renamed 420_Sad Emotional and Dramatic Piano.json to 420_sad-emotional-and-dramatic-piano-136898.json
# Renamed 169_Da Vinci_Medium 1.json to 169_da-vinci_medium-1-202369.json
# Renamed 55_Loneliness_Outro.json to 55_loneliness_outro-202380.json
# Renamed 288_Inspirational Epic.json to 288_inspirational-epic-224660.json
# Renamed 164_Solas.json to 164_solas-203831.json
# Renamed 462_Piano Sleep Music.json to 462_piano-sleep-music-166440.json
# Renamed 90_Waltz in A Minor - Chopin (Classical Piano).json to 90_waltz-in-a-minor-chopin-classical-piano-216329.json
# Renamed 408_Time Has Come.json to 408_time-has-come-203034.json
# Renamed 454_Ancient Legend.json to 454_ancient-legend-187639.json
# Renamed 279_Khi Tình Yêu Nở Hoa - Nhạc Nền Video.json to 279_khi-tinh-yeu-no-hoa-nhac-nen-video-227815.json
# Renamed 256_Soft ambient.json to 256_soft-ambient-10782.json
# Renamed 450_Pictures of Memories.json to 450_pictures-of-memories-148564.json
# Renamed 312_Legacy of Handel. Passacaglia Background music for video vlog 1 minute.json to 312_legacy-of-handel-passacaglia-background-music-for-video-vlog-1-minute-191896.json
# Renamed 148_Tràn Đầy Năng Lượng Cho Ngày Mới - Piano Cafe.json to 148_tran-ay-nang-luong-cho-ngay-moi-piano-cafe-227830.json
# Renamed 104_Heroes among us. Dramatic orchestral background music for video 30sec.json to 104_heroes-among-us-dramatic-orchestral-background-music-for-video-30sec-203754.json
# Renamed 274_Uống Nước Nhớ Nguồn - Piano BGM.json to 274_tha-hon-troi-theo-dong-nuoc-thenh-thang-piano-bgm-227808.json
# Renamed 365_Dramatic background orchestral hip hop music for vlog video. G Minor.json to 365_dramatic-background-orchestral-hip-hop-music-for-vlog-video-g-minor-176719.json
# Renamed 394_Inspiring Epic Trailer.json to 394_inspiring-epic-trailer-158075.json
# Renamed 341_Endless Beauty (Main).json to 341_endless-beauty-main-11545.json
# Renamed 333_Serenity (Inspiring and Calm Piano Background).json to 333_serenity-inspiring-and-calm-piano-background-221137.json
# Renamed 210_Emotional Cinematic_Medium 1.json to 210_emotional-cinematic_medium-1-186761.json
# Renamed 97_Winter Legacy. The Four Seasons Antonio Vivaldi Hip-Hop version 21 sec.json to 97_winter-legacy-the-four-seasons-antonio-vivaldi-hip-hop-version-21-sec-201036.json
# Renamed 309_My Love_43sec.json to 309_my-love_43sec-177578.json
# Renamed 259_The Art of Letting Go.json to 259_the-art-of-letting-go-225625.json
# Renamed 201_Meeting the Stars. Epic background orchestral music for video 33second.json to 201_meeting-the-stars-epic-background-orchestral-music-for-video-33second-197575.json
# Renamed 293_Dramatic Horror Cinematic Epic Trailer Action Intro Opener.json to 293_dramatic-horror-cinematic-epic-trailer-action-intro-opener-115496.json
# Renamed 81_Anthem of Victory.json to 81_anthem-of-victory-111206.json
# Renamed 377_The Adventures of Mr. Hardy_30sec.json to 377_the-adventures-of-mr-hardy_30sec-175535.json
# Renamed 339_Dramatic Documentary Cinematic Suspense - Coming For You (Short Ver.).json to 339_dramatic-documentary-cinematic-suspense-coming-for-you-short-ver-187171.json
# Renamed 268_Time - Emotional Music (Piano & Orchestral).json to 268_time-emotional-music-piano-amp-orchestral-215741.json
# Renamed 390_Wedding love Story.json to 390_wedding-love-story-110055.json
# Renamed 434_Creative Rise_40sec.json to 434_creative-rise_40sec-178302.json
# Renamed 30_Solas x Interstellar.json to 30_solas-x-interstellar-225036.json
# Renamed 43_Live To Love.json to 43_live-to-love-225755.json
# Renamed 26_inner peace.json to 26_inner-peace-222482.json
# Renamed 165_Endless Elegance.json to 165_endless-elegance-225764.json
# Renamed 149_Mình Cùng Về Quê Xây Căn Nhà Nhỏ - Piano BGM.json to 149_minh-cung-ve-que-xay-can-nha-nho-piano-bgm-227832.json
# Renamed 119_Loneliness_Medium 1.json to 119_loneliness_medium-1-202382.json
# Renamed 39_Thinking Of Good Time - Soft Piano Music.json to 39_thinking-of-good-time-soft-piano-music-201837.json
# Renamed 181_The Blade_Main.json to 181_the-blade_main-190862.json
# Renamed 8_Price of Freedom.json to 8_price-of-freedom-33106.json
# Renamed 424_Interstellar Space Travel.json to 424_interstellar-space-travel-141121.json
# Renamed 414_Deep Cinematic Ballad_37sec.json to 414_deep-cinematic-ballad_37sec-178305.json
# Renamed 68_idea 10.json to 68_idea-10-203609.json
# Renamed 28_Epicaly.json to 28_epicaly-113907.json
# Renamed 31_morning in the mountains.json to 31_morning-in-the-mountains-201840.json
# Renamed 423_꿈의 멜로디.json to 423_-225629.json
# Renamed 301_Viola (Cinematic Emotional Storytelling).json to 301_viola-cinematic-emotional-storytelling-204156.json
# Renamed 337_Medieval Life.json to 337_medieval-life-215103.json
# Renamed 360_Shots Of Memories.json to 360_shots-of-memories-209060.json
# Renamed 49_Emotional Inspiring Epic Trailer.json to 49_emotional-inspiring-epic-trailer-11258.json
# Renamed 168_Warrior_59sec.json to 168_warrior_59sec-192840.json
# Renamed 388_The King_60sec.json to 388_the-king_60sec-176768.json
# Renamed 473_Lovely Moment.json to 473_lovely-moment-211470.json
# Renamed 361_Epic background music for short video Dramatic orchestral instrumental.json to 361_epic-background-music-for-short-video-dramatic-orchestral-instrumental-176718.json
# Renamed 228_Story of Heroes.json to 228_story-of-heroes-200149.json
# Renamed 411_Human Greed.json to 411_human-greed-226627.json
# Renamed 441_Blessed  (EXTENDED VERSION).json to 441_blessed-extended-version-121177.json
# Renamed 159_Medieval Fantasy.json to 159_medieval-fantasy-142837.json
# Renamed 403_Epic Cinematic Intro_60sec.json to 403_epic-cinematic-intro_60sec-178311.json
# Renamed 222_Epic background music for short video 1 minute orchestral Hip Hop.json to 222_epic-background-music-for-short-video-1-minute-orchestral-hip-hop-144435.json
# Renamed 198_Uplifting Piano Is.json to 198_uplifting-piano-is-112841.json
# Renamed 307_La Valse de Lune (Beautiful Piano Piece).json to 307_la-valse-de-lune-beautiful-piano-piece-200131.json
# Renamed 32_Solas x Interstellar (Piano).json to 32_solas-x-interstellar-piano-223676.json
# Renamed 4_Majestic Voyage.json to 4_majestic-voyage-200663.json
# Renamed 186_Für Elise - Beethoven.json to 186_fur-elise-beethoven-216331.json
# Renamed 426_The Story Unfolds (Cinematic Move Background Music).json to 426_the-story-unfolds-cinematic-move-background-music-203124.json
# Renamed 22_Loves Serenade.json to 22_loves-serenade-188266.json
# Renamed 154_Constellation of Future Memories [Beautiful Piano].json to 154_constellation-of-future-memories-beautiful-piano-222166.json
# Renamed 276_Piano Không Lời Văn Phòng Công Ty - Travel Vlog, Du Lịch, Youtuber.json to 276_piano-khong-loi-van-phong-cong-ty-travel-vlog-du-lich-youtuber-227822.json
# Renamed 401_Cinematic Dark Trailer_57sec.json to 401_cinematic-dark-trailer_57sec-178300.json
# Renamed 76_golden hour- Beautiful Piano Music.json to 76_moonlit-night-relaxing-piano-225114.json
# Renamed 258_Majestic - Dark Epic Motivational Uplifting Tense Orchestra.json to 258_majestic-dark-epic-motivational-uplifting-tense-orchestra-199297.json
# Renamed 5_Drive to Triumph.json to 5_drive-to-triumph-188794.json
# Renamed 57_Bỏ Phố Về Quê - Relaxing Piano For Youtube Video.json to 57_bo-pho-ve-que-relaxing-piano-for-youtube-video-227835.json
# Renamed 247_Alive- Emotional Minimal Ambient Piano Inspirational.json to 247_alive-emotional-minimal-ambient-piano-inspirational-219418.json
# Renamed 33_Afterglow - Atmospheric Cinematic Piano.json to 33_afterglow-atmospheric-cinematic-piano-225035.json
# Renamed 379_the first star -Calm Relaxing Piano Solo Music.json to 379_the-first-star-calm-relaxing-piano-solo-music-141920.json
# Renamed 240_Creative Rise_Medium.json to 240_creative-rise_medium-178304.json
# Renamed 95_Emotional Thoughtful Piano (Thinking In Silence).json to 95_emotional-thoughtful-piano-thinking-in-silence-141580.json
# Renamed 472_Soft adventure classical instrumental.json to 472_soft-adventure-classical-instrumental-226016.json
# Renamed 223_Trapped Flames.json to 223_trapped-flames-226275.json
# Renamed 62_Mariage d'Amour - Beautiful Ambient Piano.json to 62_mariage-dx27amour-beautiful-ambient-piano-219962.json
# Renamed 124_Meeting the Stars. Epic background orchestral music for video 1 min.json to 124_meeting-the-stars-epic-background-orchestral-music-for-video-1-min-197577.json
# Renamed 406_Deep Cinematic Ballad_42sec.json to 406_deep-cinematic-ballad_42sec-178307.json
# Renamed 82_Emotional Cinematic Inspirational Piano (MAIN).json to 82_emotional-cinematic-inspirational-piano-main-10524.json
# Renamed 128_Verdant Vivaldi.json to 128_verdant-vivaldi-205627.json
# Renamed 466_History In The Heart.json to 466_history-in-the-heart-203316.json
# Renamed 192_DIM News Flash - 5.json to 192_dim-news-flash-5-227135.json
# Renamed 6_Motivational Epic Music _ Inspiring Cinematic Background Music.json to 6_motivational-epic-music-inspiring-cinematic-background-music-124265.json
# Renamed 180_TIME.json to 180_time-166273.json
# Renamed 281_Calming Piano Music  For Sleep - Relaxing Piano For Youtube Video.json to 281_calming-piano-music-for-sleep-relaxing-piano-for-youtube-video-227818.json
# Renamed 106_mia & sebastian x je te laisserai des mots.json to 106_mia-amp-sebastian-x-je-te-laisserai-des-mots-225722.json
# Renamed 474_We wish you a Merry Christmas_56sec.json to 474_we-wish-you-a-merry-christmas_56sec-174156.json
# Renamed 144_Biển Tĩnh Lặng Của Tâm Hồn - Piano Relaxing (Instagram Music).json to 144_bien-tinh-lang-cua-tam-hon-piano-relaxing-instagram-music-227801.json
# Renamed 142_Tập Trung Cao Độ Khi Làm Việc - Piano BGM.json to 142_tap-trung-cao-o-khi-lam-viec-piano-bgm-227831.json
# Renamed 83_Dòng Nước Trôi Yên Ả Mát Lành - Piano Cafe.json to 83_dong-nuoc-troi-yen-a-mat-lanh-piano-cafe-227802.json
# Renamed 425_Calm Fantasy Harp and Strings.json to 425_calm-fantasy-harp-and-strings-197736.json
# Renamed 61_Epic emotinal inspirational.json to 61_epic-emotinal-inspirational-207071.json
# Renamed 329_Romantic piano.json to 329_romantic-piano-226813.json
# Renamed 432_Angel Piano (Main).json to 432_angel-piano-main-9625.json
# Renamed 134_Inspiring Epic Motivation Cinematic Trailer.json to 134_inspiring-epic-motivation-cinematic-trailer-11218.json
# Renamed 375_Nature.json to 375_nature-225116.json
# Renamed 429_Cinematic Epical Day.json to 429_cinematic-epical-day-12953.json
# Renamed 374_Crying Piano [Solitude - Clavier].json to 374_crying-piano-solitude-clavier-212490.json
# Renamed 92_Inspirational Sentimental Romantic.json to 92_inspirational-sentimental-romantic-116955.json
# Renamed 15_Rise Above.json to 15_rise-above-178316.json
# Renamed 152_Uplifting Life.json to 152_uplifting-life-128376.json
# Renamed 292_Fall - sad autumn piano.json to 292_fall-sad-autumn-piano-216343.json
# Renamed 416_My Love_34sec.json to 416_my-love_34sec-177576.json
# Renamed 60_Beyond Horizons.json to 60_beyond-horizons-201654.json
# Renamed 334_아기들의 자장가2.json to 334_2-225631.json
# Renamed 17_Power Play.json to 17_power-play-168168.json
# Renamed 255_evening glow - Beautiful Piano Music For Videos.json to 255_evening-glow-beautiful-piano-music-for-videos-221776.json
# Renamed 100_Sad Violin.json to 100_sad-violin-150146.json
# Renamed 282_Mặt Hồ Phẳng Lặng Phản Chiếu Cảnh Trời Mây - Piano Cafe.json to 282_mat-ho-phang-lang-phan-chieu-canh-troi-may-piano-cafe-227811.json
# Renamed 491_Inspirational Drama.json to 491_inspirational-drama-119952.json
# Renamed 13_Eco Technology.json to 13_eco-technology-145636.json
# Renamed 397_The Lights of the Village.json to 397_the-lights-of-the-village-190674.json
# Renamed 296_Wander.json to 296_wander-143535.json
# Renamed 355_Blockbuster Trailer Ident.json to 355_blockbuster-trailer-ident-210400.json
# Renamed 44_Award - Adventure Epic Inspiring Cinematic Orchestra.json to 44_award-adventure-epic-inspiring-cinematic-orchestra-214102.json
# Renamed 298_No Idea - Soft Piano Music.json to 298_no-idea-soft-piano-music-225713.json
# Renamed 157_Fortnight - peaceful piano.json to 157_fortnight-peaceful-piano-226845.json
# Renamed 336_Spellcraft.json to 336_spellcraft-142264.json
# Renamed 368_June Medium.json to 368_june-medium-226399.json
# Renamed 234_twentieth of august [calm piano].json to 234_twentieth-of-august-calm-piano-221783.json
# Renamed 253_Believe in Miracle by PrabajithK.json to 253_believe-in-miracle-by-prabajithk-121041.json
# Renamed 275_Thả Hồn Trôi Theo Dòng Nước Thênh Thang - Piano BGM.json to 275_uong-nuoc-nho-nguon-piano-bgm-227797.json
# Renamed 123_Fight.json to 123_fight-142564.json
# Renamed 203_Epic.json to 203_epic-210868.json
# Renamed 372_Emotional Connection.json to 372_emotional-connection-226396.json
# Renamed 378_Powerful Emotional Epic.json to 378_powerful-emotional-epic-174136.json
# Renamed 115_Heroes among us. Orchestral hip-hop version Background music for video.json to 115_heroes-among-us-orchestral-hip-hop-version-background-music-for-video-203771.json
# Renamed 347_Reborn (Epic Movie Theme) INSTRUMENTAL.json to 347_reborn-epic-movie-theme-instrumental-212902.json
# Renamed 171_Mặt Nước Tĩnh Lặng Cảm Thấy Thật Bình Yên - Nhạc Nền Video.json to 171_mat-nuoc-tinh-lang-cam-thay-that-binh-yen-nhac-nen-video-227807.json
# Renamed 217_Loneliness_36sec.json to 217_loneliness_36sec-202379.json
# Renamed 338_Heroes of the Realm of Camelot.json to 338_heroes-of-the-realm-of-camelot-223579.json
# Renamed 98_Era of Cyborgs. Orchestral Slap House. Background music for video.json to 98_era-of-cyborgs-orchestral-slap-house-background-music-for-video-199956.json
# Renamed 220_Chance meeting. Waltz hip-hop version. Background music for video vlog.json to 220_chance-meeting-waltz-hip-hop-version-background-music-for-video-vlog-193847.json
# Renamed 405_Inspirational Asia.json to 405_inspirational-asia-116956.json
# Renamed 489_Magic Christmas_36sec.json to 489_magic-christmas_36sec-177541.json
# Renamed 167_Background epic piano music for short video vlog, advertising 1 minute.json to 167_background-epic-piano-music-for-short-video-vlog-advertising-1-minute-180911.json
# Renamed 46_Cinematic Fairy Tale Story (Main).json to 46_cinematic-fairy-tale-story-main-8697.json
# Renamed 448_The Epic Intro Music.json to 448_the-epic-intro-music-111860.json
# Renamed 25_Beautiful Things - piano.json to 25_beautiful-things-piano-222056.json
# Renamed 63_Wings of Freedom (No Copyright Motivational Music).json to 63_wings-of-freedom-no-copyright-motivational-music-226184.json
# Renamed 369_First Petal.json to 369_first-petal-226392.json
# Renamed 246_Softer Love.json to 246_softer-love-203834.json
# Renamed 287_Magic Christmas_Medium.json to 287_magic-christmas_medium-177545.json
# Renamed 175_Militant Amelia. Dramatic orchestral background music for video 34 sec.json to 175_militant-amelia-dramatic-orchestral-background-music-for-video-34-sec-205319.json
# Renamed 486_Action Intro Trailer.json to 486_action-intro-trailer-210365.json
# Renamed 479_Resistance.json to 479_resistance-142554.json
# Renamed 138_Cinematic Piano - Epic Hopes.json to 138_cinematic-piano-epic-hopes-224653.json
# Renamed 21_Epic Emotional_Long.json to 21_epic-emotional_long-197089.json
# Renamed 80_Storm Rising.json to 80_this-is-epic-115231.json
# Renamed 237_Romantic piano background music for short video vlog, blog 1 minute.json to 237_romantic-piano-background-music-for-short-video-vlog-blog-1-minute-193855.json
# Renamed 493_Endless World.json to 493_endless-world-200146.json
# Renamed 16_Unlimited Motivation.json to 16_unlimited-motivation-158250.json
# Renamed 494_For Documentary.json to 494_for-documentary-158070.json
# Renamed 45_Peaceful Piano Background Music.json to 45_peaceful-piano-background-music-218762.json
# Renamed 331_Strategist #1.json to 331_strategist-1-220873.json
# Renamed 127_Emotional Piano.json to 127_emotional-piano-226808.json
# Renamed 392_Bach - Violin Concerto in A minor - 3. Movement - BWV 1041.json to 392_bach-violin-concerto-in-a-minor-3-movement-bwv-1041-183738.json
# Renamed 284_Mặt Hồ Phẳng Lặng Như Gương Phản Chiếu Bầu Trời Trong Vắt - Piano Cafe.json to 284_mat-ho-phang-lang-nhu-guong-phan-chieu-bau-troi-trong-vat-piano-cafe-227814.json
# Renamed 295_The King_Medium.json to 295_the-king_medium-176770.json
# Renamed 34_Loneliness_Long.json to 34_loneliness_long-202383.json
# Renamed 172_A Gentle Breeze.json to 172_a-gentle-breeze-189206.json
# Renamed 438_Deep Cinematic Ballad_36sec.json to 438_deep-cinematic-ballad_36sec-178306.json
# Renamed 303_Positive short background music for video. Positive spring day 1 min.json to 303_positive-short-background-music-for-video-positive-spring-day-1-min-194445.json
# Renamed 216_fall asleep  [Piano Music].json to 216_fall-asleep-piano-music-218341.json
# Renamed 108_One Last Time.json to 108_one-last-time-141289.json
# Renamed 272_Vũ Điệu Của Những Vì Sao - Relaxing Piano For Youtube Video.json to 272_vu-ieu-cua-nhung-vi-sao-relaxing-piano-for-youtube-video-227796.json
# Renamed 485_Sky Dive.json to 485_sky-dive-176535.json
# Renamed 84_Xoa Dịu Nỗi Lòng - Piano BGM.json to 84_xoa-diu-noi-long-piano-bgm-227803.json
# Renamed 340_Hopeful Piano.json to 340_hopeful-piano-112621.json
# Renamed 387_The other side - Beautiful Piano Music.json to 387_the-other-side-beautiful-piano-music-205579.json
# Renamed 182_Deep Cinematic Ballad_60sec.json to 182_deep-cinematic-ballad_60sec-178308.json
# Renamed 176_Love Story (Sentimental Emotional).json to 176_love-story-sentimental-emotional-221812.json
# Renamed 37_Warrior_Medium.json to 37_warrior_medium-192841.json
# Renamed 267_Evening Breeze.json to 267_evening-breeze-214352.json
# Renamed 327_The Sunset of Your Sun.json to 327_the-sunset-of-your-sun-216986.json
# Renamed 184_We Confidently Go To Victory.json to 184_we-confidently-go-to-victory-12006.json
# Renamed 50_Battle Of The Dragons.json to 50_battle-of-the-dragons-8037.json
# Renamed 458_Gravity.json to 458_gravity-193874.json
# Renamed 143_Hoà Tấu Nhẹ Nhàng Tập Trung Làm Việc - Piano Cafe.json to 143_hoa-tau-nhe-nhang-tap-trung-lam-viec-piano-cafe-227825.json
# Renamed 58_Dòng Sông Phẳng Lặng Như Tờ - Relaxing Piano For Youtube Video.json to 58_dong-song-phang-lang-nhu-to-relaxing-piano-for-youtube-video-227805.json
# Renamed 273_Relaxing Piano Music - Nhạc Nền Video.json to 273_relaxing-piano-music-nhac-nen-video-227817.json
# Renamed 326_Funny music background for video, stories. Positive spring day 30 sec.json to 326_funny-music-background-for-video-stories-positive-spring-day-30-sec-194443.json
# Renamed 190_Nature.json to 190_nature-99499.json
# Renamed 137_Soothing Piano Harmony.json to 137_soothing-piano-harmony-224434.json
# Renamed 367_Emotional Piano Sad Background Music For Videos.json to 367_emotional-piano-sad-background-music-for-videos-221779.json
# Renamed 59_faded - Relaxing Piano Music.json to 59_faded-relaxing-piano-music-218335.json
# Renamed 487_The HIdden Diamonds.json to 487_the-hidden-diamonds-209034.json
# Renamed 398_Symphony of Emotion (1).json to 398_symphony-of-emotion-1-209875.json
# Renamed 71_Militant Amelia. Orchestral hip-hop background music for video vlog.json to 71_militant-amelia-orchestral-hip-hop-background-music-for-video-vlog-205323.json
# Renamed 325_Never Leave.json to 325_never-leave-221903.json
# Renamed 437_The Adventures of Mr. Hardy_60sec.json to 437_the-adventures-of-mr-hardy_60sec-175536.json
# Renamed 197_Epic inspirational  Cinematic Trailer.json to 197_epic-inspirational-cinematic-trailer-204849.json
# Renamed 118_Epic Emotional_Medium 1.json to 118_epic-emotional_medium-1-197086.json
# Renamed 322_Renaissance (Epic Orchestral Cinematic).json to 322_renaissance-epic-orchestral-cinematic-219596.json
# Renamed 304_reading - soft piano.json to 304_reading-soft-piano-221781.json
# Renamed 323_Epic Piano Music - Deception Point.json to 323_epic-piano-music-deception-point-219963.json
# Renamed 7_Awaken.json to 7_awaken-136824.json
# Renamed 116_Slow Motion.json to 116_slow-motion-121841.json
# Renamed 195_Melody of Nature (Main).json to 195_melody-of-nature-main-6672.json
# Renamed 452_Sentimental Action.json to 452_sentimental-action-224796.json
# Renamed 269_Clockwork Chaos (Dark Trailer Intro).json to 269_clockwork-chaos-dark-trailer-intro-202223.json
# Renamed 389_Christmas In the Village.json to 389_christmas-in-the-village-176566.json
# Renamed 85_Lặng Nhìn Dòng Nước Cuốn Trôi Theo Bao Nỗi Ưu Phiền - Piano BGM.json to 85_lang-nhin-dong-nuoc-cuon-troi-theo-bao-noi-uu-phien-piano-bgm-227806.json
# Renamed 449_Background music for short video vlog. Funny light accompanying.json to 449_background-music-for-short-video-vlog-funny-light-accompanying-168574.json
# Renamed 407_War is Coming.json to 407_war-is-coming-103662.json
# Renamed 67_Broken Sonata - Sad Piano.json to 67_broken-sonata-sad-piano-201839.json
# Renamed 66_Moon Rain - Beautiful Piano Music.json to 66_moon-rain-beautiful-piano-music-223674.json
# Renamed 69_Epic Emotional_Short 1.json to 69_epic-emotional_short-1-197085.json
# Renamed 496_TIME (Long version).json to 496_time-long-version-166583.json
# Renamed 227_Inspiring Cinematic Asia.json to 227_inspiring-cinematic-asia-116200.json
# Renamed 451_Sad Piano - Background Music For Videos.json to 451_sad-piano-background-music-for-videos-7573.json
# Renamed 93_Intense Orchestral Drama.json to 93_intense-orchestral-drama-224432.json
# Renamed 463_Epic Cinematic Intro_Medium 1.json to 463_epic-cinematic-intro_medium-1-178312.json
# Renamed 470_beneath the infinite sky.json to 470_beneath-the-infinite-sky-225669.json
# Renamed 435_Cheerful light waltz for short video vlog, advertising, promo 40 sec.json to 435_cheerful-light-waltz-for-short-video-vlog-advertising-promo-40-sec-182220.json
# Renamed 191_Whispers of the Desert Wind.json to 191_whispers-of-the-desert-wind-199494.json
# Renamed 219_Let's get this done.json to 219_letx27s-get-this-done-154533.json
# Renamed 226_Relaxing, Sad Piano Music - Lost Dreams.json to 226_relaxing-sad-piano-music-lost-dreams-209547.json
# Renamed 151_Dramatic Atmosphere with Piano and Violin.json to 151_dramatic-atmosphere-with-piano-and-violin-143149.json
# Renamed 94_Countdown.json to 94_countdown-149998.json
# Renamed 35_Da Vinci_Long.json to 35_da-vinci_long-202372.json
# Renamed 332_Inspiring Emotional Uplifting Piano.json to 332_inspiring-emotional-uplifting-piano-221780.json
# Renamed 492_Hybrid Trailer Epic.json to 492_hybrid-trailer-epic-12954.json
# Renamed 221_Passacaglia.json to 221_passacaglia-204294.json
# Renamed 178_Shooting stars.json to 178_shooting-stars-142600.json
# Renamed 145_Tập Trung Vào Công Việc - Piano Relaxing (Instagram Music).json to 145_tap-trung-vao-cong-viec-piano-relaxing-instagram-music-227826.json
# Renamed 70_The Last Watchman (Epic Cinematic Noir Orchestra).json to 70_the-last-watchman-epic-cinematic-noir-orchestra-221141.json
# Renamed 183_Loneliness_51sec.json to 183_loneliness_51sec-202381.json
# Renamed 262_Warrior_52sec.json to 262_warrior_52sec-192839.json
# Renamed 483_World Travel.json to 483_world-travel-142838.json
# Renamed 14_Cinematic Time Lapse.json to 14_cinematic-time-lapse-115672.json
# Renamed 300_Deep Cinematic Ballad_Medium.json to 300_deep-cinematic-ballad_medium-178309.json
# Renamed 430_Peaceful Ripples.json to 430_peaceful-ripples-224639.json
# Renamed 245_Piano Sad Background Music For Videos.json to 245_piano-sad-background-music-for-videos-221777.json
# Renamed 484_Ten Minutes of Ambient Piano Relaxation.json to 484_ten-minutes-of-ambient-piano-relaxation-146966.json
# Renamed 249_Serpents of War.json to 249_serpents-of-war-226914.json
# Renamed 385_Dòng Sông Trôi Qua Đi Làm Sao Tắm Lại Được - Nhạc Nền Video.json to 385_dong-song-troi-qua-i-lam-sao-tam-lai-uoc-nhac-nen-video-227799.json
# Renamed 18_Piano Moment.json to 18_piano-moment-9835.json
# Renamed 330_whisper in the rain.json to 330_whisper-in-the-rain-225656.json
# Renamed 53_Meeting the Stars. Dramatic cinematic background music for epic video.json to 53_meeting-the-stars-dramatic-cinematic-background-music-for-epic-video-197578.json
# Renamed 257_Love Of My Life.json to 257_love-of-my-life-211472.json
# Renamed 306_My Little Garden of Eden.json to 306_my-little-garden-of-eden-112845.json
# Renamed 311_Dark - Action Aggressive Anxiety Horror Countdown Trailer Intro.json to 311_dark-action-aggressive-anxiety-horror-countdown-trailer-intro-201375.json
# Renamed 91_Motivational Epic Advertising.json to 91_motivational-epic-advertising-186817.json
# Renamed 319_Inspirational Piano.json to 319_inspirational-piano-141480.json
# Renamed 266_Apocalypse.json to 266_apocalypse-128378.json
# Renamed 130_Winter Legacy. The Four Seasons Antonio Vivaldi Hip-Hop version 33 sec.json to 130_winter-legacy-the-four-seasons-antonio-vivaldi-hip-hop-version-33-sec-201037.json
# Renamed 199_Tense Sad Piano.json to 199_tense-sad-piano-111679.json
# Renamed 236_Always With Me, Always With You (Piano Long).json to 236_always-with-me-always-with-you-piano-long-21257.json
# Renamed 224_Epicaly - Short.json to 224_epicaly-short-113909.json
# Renamed 242_Ambient Inspiration.json to 242_ambient-inspiration-136110.json
# Renamed 316_embrace the journey, not the destination.json to 316_embrace-the-journey-not-the-destination-225670.json
# Renamed 150_Victorian Violin Waltz.json to 150_victorian-violin-waltz-222298.json
# Renamed 412_Epical Cinematic.json to 412_epical-cinematic-158068.json
# Renamed 229_Cinematic Adventure _ Alive.json to 229_cinematic-adventure-alive-135518.json
# Renamed 433_Vivaldi - Four Seasons _Winter_ - RV 297 - Arr. for Strings.json to 433_vivaldi-four-seasons-quotwinterquot-rv-297-arr-for-strings-185593.json
# Renamed 206_THE WAY HOME.json to 206_the-way-home-6674.json
# Renamed 263_Legacy of Chopin. Nocturne op.9 No.2 Hip-Hop version. Background music.json to 263_legacy-of-chopin-nocturne-op9-no2-hip-hop-version-background-music-189777.json
# Renamed 174_Cinematic Ambient Piano.json to 174_cinematic-ambient-piano-118668.json
# Renamed 352_Hiding place in the Forest.json to 352_hiding-place-in-the-forest-111724.json
# Renamed 125_Simple Piano Melody.json to 125_simple-piano-melody-9834.json
# Renamed 252_Inspiring Epic Fly (Cinematic Action Triumphant).json to 252_inspiring-epic-fly-cinematic-action-triumphant-186813.json
# Renamed 122_Positive spring day. Orchestral hip-hop ver Background music for video.json to 122_positive-spring-day-orchestral-hip-hop-ver-background-music-for-video-194370.json
# Renamed 289_Revival of Chopin Waltz. Hip-Hop version. Background piano music.json to 289_revival-of-chopin-waltz-hip-hop-version-background-piano-music-182223.json
# Renamed 477_Cheerful Cinematic Song (without solo guitar).json to 477_cheerful-cinematic-song-without-solo-guitar-10709.json
# Renamed 202_Emotional Cinematic_34sec.json to 202_emotional-cinematic_34sec-186758.json
# Renamed 453_Dramatic Suspense.json to 453_dramatic-suspense-116798.json
# Renamed 147_Bỏ Phố Thị Ta Trở Về Với Thôn Quê - Piano Cafe.json to 147_bo-pho-thi-ta-tro-ve-voi-thon-que-piano-cafe-227833.json
# Renamed 362_Believe In Yourself (Inspiring Piano Hopeful Epic Trailer).json to 362_believe-in-yourself-inspiring-piano-hopeful-epic-trailer-219623.json
# Renamed 250_Timeless Sonata.json to 250_timeless-sonata-219953.json
# Renamed 56_Warrior_30sec.json to 56_warrior_30sec-192838.json
# Renamed 343_The Magic Tree.json to 343_the-magic-tree-150606.json
# Renamed 400_Unfailing Love.json to 400_unfailing-love-224304.json
# Renamed 270_Adventure Intro.json to 270_adventure-intro-210375.json
# Renamed 36_Let the Mystery Unfold.json to 36_let-the-mystery-unfold-122118.json
# Renamed 428_Piano and Nature Sounds.json to 428_piano-and-nature-sounds-222463.json
# Renamed 260_Epic Motivational Trailer.json to 260_epic-motivational-trailer-129210.json
# Renamed 162_Winter Legacy. The Four Seasons Antonio Vivaldi Hip-Hop version 39 sec.json to 162_winter-legacy-the-four-seasons-antonio-vivaldi-hip-hop-version-39-sec-201038.json
# Renamed 38_Epic Action.json to 38_epic-action-113888.json
# Renamed 294_Sorrowful Serenade.json to 294_sorrowful-serenade-208297.json
# Renamed 442_Forget.json to 442_forget-16026.json
# Renamed 160_Lost Illusions (Emotional Cinematic Orchestra).json to 160_lost-illusions-emotional-cinematic-orchestra-207193.json
# Renamed 173_Cozy Autumn - Beautiful Piano Song.json to 173_cozy-autumn-beautiful-piano-song-201836.json
# Renamed 313_Experience x Interstellar.json to 313_experience-x-interstellar-215739.json
# Renamed 87_Con Nước Trôi Miên Mang Đưa Ta Vào Chốn Phiêu Bồng - Piano Cafe.json to 87_con-nuoc-troi-mien-mang-ua-ta-vao-chon-phieu-bong-piano-cafe-227804.json
# Renamed 153_Epic Cinematic Intro_Medium 2.json to 153_epic-cinematic-intro_medium-2-178313.json
# Renamed 478_Epic Colors.json to 478_epic-colors-142337.json
# Renamed 248_Light, cheerful short background music for video vlogs. Funny hip hop.json to 248_light-cheerful-short-background-music-for-video-vlogs-funny-hip-hop-194442.json
# Renamed 305_Cinematic Melody (Main).json to 305_cinematic-melody-main-9785.json
# Renamed 467_A Sinister Power Rising - Epic Dark Gothic Soundtrack.json to 467_a-sinister-power-rising-epic-dark-gothic-soundtrack-15021.json
# Renamed 468_Inspiring Landscape.json to 468_inspiring-landscape-121838.json
# Renamed 480_Silver Sparkles.json to 480_silver-sparkles-150619.json
# Renamed 136_Loneliness_Medium 2.json to 136_loneliness_medium-2-202378.json
# Renamed 79_Heroes among us. Cinematic orchestral background music for video 60sec.json to 79_storm-rising-227182.json
# Renamed 427_Cinematic Dramatic Documentary Piano.json to 427_cinematic-dramatic-documentary-piano-142259.json
# Renamed 344_Triumphant (Long).json to 344_triumphant-long-6673.json
# Renamed 135_Wake Me Up.json to 135_wake-me-up-223675.json
# Renamed 310_Epic Cinematic Drama_60sec.json to 310_epic-cinematic-drama_60sec-187362.json
# Renamed 418_Victory's Anthem War.json to 418_victoryx27s-anthem-war-212726.json
# Renamed 499_Tension.json to 499_tension-113661.json
# Renamed 177_Background music for video, promo, stories. Positive spring day 27 sec.json to 177_background-music-for-video-promo-stories-positive-spring-day-27-sec-194441.json
# Renamed 78_Cinematic Documentary Piano.json to 78_heroes-among-us-cinematic-orchestral-background-music-for-video-60sec-203756.json
# Renamed 421_The Crystal Cave.json to 421_the-crystal-cave-198981.json
# Renamed 381_Learn To Fly.json to 381_learn-to-fly-169153.json
# Renamed 261_Eternal Ascent.json to 261_eternal-ascent-227127.json
# Renamed 445_Apocalypse_v1_60sec.json to 445_apocalypse_v1_60sec-178284.json
# Renamed 349_Cinematic Dark Trailer_43sec.json to 349_cinematic-dark-trailer_43sec-178297.json
# Renamed 351_Eclipse (Beautiful Piano).json to 351_eclipse-beautiful-piano-200127.json
# Renamed 131_Sad Waltz (Piano).json to 131_sad-waltz-piano-216330.json
# Renamed 161_Heroes among us. Dramatic background music for video vlog 1 minute.json to 161_heroes-among-us-dramatic-background-music-for-video-vlog-1-minute-203757.json
# Renamed 88_Bỏ Thành Thị Về Quê Lập Nghiệp.json to 88_bo-thanh-thi-ve-que-lap-nghiep-227836.json
# Renamed 457_Illuminati - weird piano meme.json to 457_illuminati-weird-piano-meme-218387.json
# Renamed 27_Moonlight Echoes.json to 27_moonlight-echoes-212720.json
# Renamed 395_Say Yes to Heaven.json to 395_say-yes-to-heaven-212491.json
# Renamed 72_Winter Legacy. The Four Seasons Antonio Vivaldi Hip-Hop version 54 sec.json to 72_winter-legacy-the-four-seasons-antonio-vivaldi-hip-hop-version-54-sec-201039.json
# Renamed 314_Heroic Quest.json to 314_heroic-quest-186932.json
# Renamed 391_Epic piano background music for video vlog, blog, advertising 1 minute.json to 391_epic-piano-background-music-for-video-vlog-blog-advertising-1-minute-189907.json
# Renamed 302_Emotional Cinematic_Medium 2.json to 302_emotional-cinematic_medium-2-186760.json
# Renamed 141_Beautiful Relaxing Music for Stress Relief - Piano Cafe.json to 141_beautiful-relaxing-music-for-stress-relief-piano-cafe-227819.json
# Renamed 417_The King_30sec.json to 417_the-king_30sec-176769.json
# Renamed 64_Warrior_Long.json to 64_warrior_long-192842.json
# Renamed 9_Waterfall.json to 9_waterfall-140894.json
# Renamed 469_Epic music, background instrumental for video. Dramatic Hip Hop beat.json to 469_epic-music-background-instrumental-for-video-dramatic-hip-hop-beat-176723.json
# Renamed 139_dialogues with the past.json to 139_dialogues-with-the-past-225668.json
# Renamed 211_Paths Crossed, Lessons Learned.json to 211_paths-crossed-lessons-learned-225617.json
# Renamed 353_Creative Rise_57sec.json to 353_creative-rise_57sec-178303.json
# Renamed 121_Slow Piano and Rain.json to 121_slow-piano-and-rain-220167.json
# Renamed 51_Honor and Sword (Main).json to 51_honor-and-sword-main-11222.json
# Renamed 238_Epic music. Short background music for video vlogs, promo 1 minute.json to 238_epic-music-short-background-music-for-video-vlogs-promo-1-minute-194801.json
# Renamed 354_Thinking Piano Music Ambience.json to 354_thinking-piano-music-ambience-225272.json
# Renamed 200_Heartbreaking (Emotional) Piano.json to 200_heartbreaking-emotional-piano-215740.json
# Renamed 356_Time Pt.3.json to 356_time-pt3-221116.json
# Renamed 481_Magic Christmas_60sec.json to 481_magic-christmas_60sec-177542.json
# Renamed 3_Science Documentary.json to 3_science-documentary-169621.json
# Renamed 19_Winter Legacy. The Four Seasons. Hip-Hop version. Background music.json to 19_winter-legacy-the-four-seasons-hip-hop-version-background-music-201042.json
# Renamed 12_Relaxing.json to 12_relaxing-145038.json
# Renamed 386_Lời Yêu Thương Ấm Áp - Travel Vlog, Du Lịch, Youtuber.json to 386_loi-yeu-thuong-am-ap-travel-vlog-du-lich-youtuber-227812.json
# Renamed 373_Cinematic Epic Trailer Background Music.json to 373_cinematic-epic-trailer-background-music-123922.json
# Renamed 364_piano Music -Lose Control.json to 364_piano-music-lose-control-219964.json
# Renamed 471_Documentary Background.json to 471_documentary-background-119940.json
# Renamed 231_Romantic Love Piano.json to 231_romantic-love-piano-150084.json
# Renamed 482_Ominous Tension.json to 482_ominous-tension-157906.json
# Renamed 209_The Shield.json to 209_the-shield-111353.json
# Renamed 476_Daybreak Melody.json to 476_daybreak-melody-224635.json
# Renamed 48_The Epic Trailer.json to 48_the-epic-trailer-12955.json
# Renamed 86_Không Gian Làm Việc Lí Tưởng - Piano Relaxing (Instagram Music).json to 86_khong-gian-lam-viec-li-tuong-piano-relaxing-instagram-music-227827.json
# Renamed 132_Militant Amelia. Epic drama orchestra background music for video 25sec.json to 132_militant-amelia-epic-drama-orchestra-background-music-for-video-25sec-205318.json
# Renamed 155_Beethoven - Concert Nr3 (Relaxing Classical Piano).json to 155_beethoven-concert-nr3-relaxing-classical-piano-216328.json
# Renamed 75_Field Grass.json to 75_golden-hour-beautiful-piano-music-203835.json
# Renamed 318_Worship Piano Instrumental Peaceful Prayer Music.json to 318_worship-piano-instrumental-peaceful-prayer-music-223373.json
# Renamed 363_Fall of Whiterun.json to 363_fall-of-whiterun-200147.json
# Renamed 1_Inspiring Cinematic Ambient.json to 1_inspiring-cinematic-ambient-116199.json
# Renamed 129_November Wind.json to 129_november-wind-224282.json
# Renamed 208_Midnight.json to 208_midnight-123895.json
# Renamed 415_Background music for video 21 sec. Legacy of Chopin Nocturne op.9 No.2.json to 415_background-music-for-video-21-sec-legacy-of-chopin-nocturne-op9-no2-189904.json
# Renamed 239_I Giorni.json to 239_i-giorni-205574.json
# Renamed 265_Taking Flight.json to 265_taking-flight-205965.json
# Renamed 109_Exciting Day (Inspiring Piano).json to 109_exciting-day-inspiring-piano-176148.json
# Renamed 96_Epic Emotional_Medium 2.json to 96_epic-emotional_medium-2-197087.json
# Renamed 232_Epic Cinematic Drama_Medium.json to 232_epic-cinematic-drama_medium-187363.json
# Renamed 179_Romantic Love Piano Song - Until I Found You.json to 179_romantic-love-piano-song-until-i-found-you-218336.json
# Renamed 243_Apocalypse_v3_59sec.json to 243_apocalypse_v3_59sec-178285.json
# Renamed 277_Peaceful Piano Music - Piano BGM.json to 277_peaceful-piano-music-piano-bgm-227820.json
# Renamed 359_Beautiful Trip.json to 359_beautiful-trip-142481.json
# Renamed 2_Risk.json to 2_risk-136788.json
# Renamed 193_Epic Cinematic Drama_54sec.json to 193_epic-cinematic-drama_54sec-187364.json
# Renamed 371_The First Days of Spring.json to 371_the-first-days-of-spring-188392.json
# Renamed 409_Note To Say Good Bye.json to 409_note-to-say-good-bye-221567.json
# Renamed 444_Blessed (Main).json to 444_blessed-main-120698.json
# Renamed 317_Peaceful Cinematic.json to 317_peaceful-cinematic-141736.json
# Renamed 112_big dreams, small steps.json to 112_big-dreams-small-steps-225666.json
# Renamed 213_Sad Moment _ Sad and Melancholy Piano Background Music.json to 213_sad-moment-sad-and-melancholy-piano-background-music-124488.json
# Renamed 278_Tư Duy Sáng Tạo Tại Văn Phòng Công Ty - Nhạc Nền Video.json to 278_tu-duy-sang-tao-tai-van-phong-cong-ty-nhac-nen-video-227824.json
# Renamed 422_Crazy Mind - piano music.json to 422_crazy-mind-piano-music-216335.json
# Renamed 113_Cinematic Action Intro.json to 113_cinematic-action-intro-210366.json
# Renamed 283_Augustyn Engty- Moonlight (Royalty Free Music).json to 283_augustyn-engty-moonlight-royalty-free-music-227203.json
# Renamed 99_Invisible - Piano Music.json to 99_invisible-piano-music-201838.json
# Renamed 382_🎹Contemporary Classical _ _Serenity's Sonata II_.json to 382_contemporary-classical-quotserenityx27s-sonata-iiquot-223893.json
# Renamed 497_Magic Inspiration.json to 497_magic-inspiration-201208.json
# Renamed 196_Virtuoso.json to 196_virtuoso-210063.json
# Renamed 328_My Love_Short.json to 328_my-love_short-177579.json
# Renamed 146_Tiếng Piano Kích Hoạt Sự Sáng Tạo - Travel Vlog, Du Lịch, Youtuber.json to 146_tieng-piano-kich-hoat-su-sang-tao-travel-vlog-du-lich-youtuber-227829.json
# Renamed 436_Epic background piano music for short video vlog, advertising 1 minute.json to 436_epic-background-piano-music-for-short-video-vlog-advertising-1-minute-182222.json
# Renamed 459_The Calm Ocean.json to 459_the-calm-ocean-212561.json
# Renamed 233_Background epic piano music for short video vlog, advertising 23 sec.json to 233_background-epic-piano-music-for-short-video-vlog-advertising-23-sec-189905.json
# Renamed 29_Sad Waltz  - Mia and Sebastian’s Theme [Piano].json to 29_sad-waltz-mia-and-sebastians-theme-piano-225723.json
# Renamed 40_Cinematic Dramatic.json to 40_cinematic-dramatic-11120.json
# Renamed 215_Inspiring Cinematic.json to 215_inspiring-cinematic-190553.json
# Renamed 335_Cinematic Dark Trailer.json to 335_cinematic-dark-trailer-130489.json
# Renamed 402_lovely brunch.json to 402_lovely-brunch-200502.json
# Renamed 102_Lost Dreams - Inspiring Cinematic Ambient.json to 102_lost-dreams-inspiring-cinematic-ambient-208164.json
# Renamed 461_Cinematic Motivational.json to 461_cinematic-motivational-136831.json
# Renamed 280_Ánh Sáng Nhỏ Trong Bóng Đêm - Relaxing Piano For Youtube Video.json to 280_anh-sang-nho-trong-bong-em-relaxing-piano-for-youtube-video-227809.json
# Renamed 188_Da Vinci_59sec.json to 188_da-vinci_59sec-202368.json
# Renamed 460_Emotional Piano.json to 460_emotional-piano-141472.json
# Renamed 23_Beautiful Piano Music - felt piano [Now We Are Free].json to 23_beautiful-piano-music-felt-piano-now-we-are-free-219961.json
# Renamed 321_The Flashback_60sec 1.json to 321_the-flashback_60sec-1-174161.json
# Renamed 218_Climax - Epic Sad Piano Song.json to 218_climax-epic-sad-piano-song-200132.json
# Renamed 166_Touch and Sound.json to 166_touch-and-sound-113676.json
# Renamed 297_Beautiful Piano.json to 297_beautiful-piano-115480.json
# Renamed 500_Two Silly Monkeys.json to 500_two-silly-monkeys-174980.json
# Renamed 495_The Power Within.json to 495_the-power-within-223332.json
# Renamed 101_Cinematic Background Inspirational.json to 101_cinematic-background-inspirational-150013.json
# Renamed 299_Lost in the Enchanted Woods.json to 299_lost-in-the-enchanted-woods-191319.json
# Renamed 105_Alice in Dark Wonderland.json to 105_alice-in-dark-wonderland-123894.json
# Renamed 24_Epic Hollywood Trailer.json to 24_epic-hollywood-trailer-9489.json
# Renamed 456_Fearsome Tipsy Pirates ( Pirates Epic Trailer ).json to 456_fearsome-tipsy-pirates-pirates-epic-trailer-200229.json
# Renamed 315_Emotional Cinematic_50sec.json to 315_emotional-cinematic_50sec-186759.json
# Renamed 140_Góc Làm Việc Chill - Relaxing Piano For Youtube Video.json to 140_goc-lam-viec-chill-relaxing-piano-for-youtube-video-227828.json
# Renamed 54_For When It Rains.json to 54_for-when-it-rains-112785.json
# Renamed 74_My Love Medium.json to 74_field-grass-115973.json
# Renamed 117_One love story. Orchestral hip-hop version. Background music for video.json to 117_one-love-story-orchestral-hip-hop-version-background-music-for-video-194766.json
# Renamed 464_journeys of the soul.json to 464_journeys-of-the-soul-225655.json
# Renamed 235_DIM Meditation 396 Hz.json to 235_dim-meditation-396-hz-227138.json
# Renamed 324_Sweet Dreams.json to 324_sweet-dreams-150475.json
# Renamed 370_Inspirational Sentimental Moments.json to 370_inspirational-sentimental-moments-204865.json
# Renamed 110_Beautiful Piano Tracks for Studying, Relaxation, Sleep - Piano BGM.json to 110_beautiful-piano-tracks-for-studying-relaxation-sleep-piano-bgm-227821.json
# Renamed 225_Background music for short video, vlog, promo Era of Cyborgs 1 minute.json to 225_background-music-for-short-video-vlog-promo-era-of-cyborgs-1-minute-199952.json
# Renamed 214_Ambient Piano.json to 214_ambient-piano-215975.json
# Renamed 446_Middle Ages.json to 446_middle-ages-147373.json
# Renamed 77_moonlit night - relaxing piano.json to 77_cinematic-documentary-piano-141467.json
# Renamed 241_arcade - piano.json to 241_arcade-piano-218340.json
# Renamed 404_Cold Cinematic Landscape.json to 404_cold-cinematic-landscape-116954.json
# Renamed 47_Relaxing Piano.json to 47_relaxing-piano-201831.json
# Renamed 126_Epic Emotional_59sec.json to 126_epic-emotional_59sec-197083.json
# Renamed 357_Una Luna - relaxing piano.json to 357_una-luna-relaxing-piano-216337.json
# Renamed 366_Busy Bees.json to 366_busy-bees-158999.json
# Renamed 10_Reflected Light.json to 10_reflected-light-147979.json
# Renamed 133_Da Vinci_Short.json to 133_da-vinci_short-202370.json
# Renamed 348_Epic background orchestral instrumental music for short videos 26 sec.json to 348_epic-background-orchestral-instrumental-music-for-short-videos-26-sec-180908.json
# Renamed 114_Softer Love - beautiful piano.json to 114_softer-love-beautiful-piano-216336.json
# Renamed 107_Militant Amelia. Dramatic background music for video vlog 1 minute.json to 107_militant-amelia-dramatic-background-music-for-video-vlog-1-minute-205321.json
# Renamed 447_The Wrath Of The Samurai.json to 447_the-wrath-of-the-samurai-226908.json
# Renamed 204_DIM News Flash - 5.json to 204_dim-news-flash-5-227133.json

# %% [markdown]
# ## 5. Create final folder

# %% [markdown]
# ### 5.1. Verify consistency
# You'll need to verify the consistency of your :
# - Renamed audiofiles
# - .json files
# - .csv rows

# %%
# verify consistency of JSON and audio filenames
'''
python script_name.py /home/user/data/audio_files \
    --csv /home/user/data/titles.csv \
    --json_folder /home/user/data/json_files
'''

# !python scripts/verify_csv-audio-json_files.py \
    audio_files/_processing/v0_{GITHUB_PROFILE_NAME} \
    --csv dataframes/filtered_by_genre/500_{genre}_tracks.csv \
    --json_folder json/json_{genre}/
# Out:
# WARNING:root:Row 410: Missing audio file with URL key '225927'
# WARNING:root:Row 475: Missing audio file with URL key '225922'
#
# Failed downloads:
# Row 410: Missing audio file with URL key '225927'
# Row 475: Missing audio file with URL key '225922'
# WARNING:root:Invalid audio filename format: desktop.ini
# WARNING:root:Invalid JSON filename format: desktop.ini
# No discrepancies found between audio and JSON files, and no duplicated audio files.

# %% [markdown]
# ### 5.2. Saving "file_count" on .env

# %%
# %%bash
#
# file_count=$(ls -1 audio_files/_processing/v0_${GITHUB_PROFILE_NAME} | wc -l)
# echo "file_count=$file_count" >> "notebooks/dataset for fine-tuning/.env"

# %% [markdown]
# ### 5.3. Create final folder, move processed files into it and backup folder

# %%
# %%bash
#
# # Read the .env file line by line
# while IFS='\=' read -r key value; do
#   # If the line contains an '=', treat it as a variable assignment
#   if [[ $key && $value ]]; then
#     # Remove leading/trailing whitespace and quotes from the value
#     value="${value//[\'\"]/}"
#     value="${value// }"
#
#     # Export the variable
#     export "$key=$value"
#   fi
# done < "notebooks/dataset for fine-tuning/.env"
#
# # Access the genre variable directly
# genre=$genre
#
# # Get the current timestamp
# timestamp=$(date +"%Y-%m-%d_%H-%M-%S")
#
# ### V0 to Backup with timestamp ###
#
# # Create the backup folder
# mkdir -p audio_files/final_backup
#
# # Create the backup folder name with the timestamp
# backup_folder_name="backup_${GITHUB_PROFILE_NAME}_${timestamp}"
#
# # Create the full backup directory path
# mkdir -p audio_files/final_backup/$backup_folder_name
#
# # Copy all audio files from the source directory to the destination
# cp -r audio_files/_processing/v0_${GITHUB_PROFILE_NAME}/* audio_files/final_backup/$backup_folder_name/
#
# # Copy all json files from the source dir to the destination
# cp -r json/json_$genre/* audio_files/final_backup/$backup_folder_name/
#
# ### V0 to Final Folder ###
#
# # Create the final folder name
# final_folder_name="${file_count}_${genre}_files_${timestamp}"
#
# # Create the new folder
# mkdir audio_files/by_genre
# mkdir audio_files/by_genre/"$final_folder_name"
#
# # Move all files from the source directory to the final folder
# mv audio_files/_processing/v0_${GITHUB_PROFILE_NAME}/* audio_files/by_genre/"$final_folder_name"/
#
# # Copy all json files from the source dir to the destination
# cp -r json/json_$genre/* audio_files/by_genre/"$final_folder_name"/
#
# #capture variables
# echo "final_folder_name=$final_folder_name" >> "notebooks/dataset for fine-tuning/.env"
# Out:
# mkdir: cannot create directory ‘audio_files/by_genre’: File exists

# %% [markdown]
# ### 5.4. Create .csv "checked"

# %% [markdown]
# - Donwload your dataframe "all-checked" (all values in "Downloaded?" column are '1') as .csv
# - Rename it like your-dataframe-**checked**
# - Move it to /sam_files/dataframes/checked

# %% [markdown]
# ### 5.5. Remove operational folders

# %%
# remove operational folders
# %cd /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files

import shutil
import os

github_profile_name = GITHUB_PROFILE_NAME

# Construct the full paths to the folders
transition_folder = f"audio_files/_processing/transition_{github_profile_name}"
v0_folder = f"audio_files/_processing/v0_{github_profile_name}"
backup_folder = f"audio_files/_processing/backup_{github_profile_name}"
json = f"json"

# Remove the folders using shutil.rmtree
for folder in [transition_folder, v0_folder, backup_folder, json]:
    try:
        shutil.rmtree(folder)
        print(f"Removed folder: {folder}")
    except OSError as e:
        print(f"Error removing folder {folder}: {e}")
# Out:
# /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files
# Removed folder: audio_files/_processing/transition_arthurcornelio88
# Removed folder: audio_files/_processing/v0_arthurcornelio88
# Removed folder: audio_files/_processing/backup_arthurcornelio88
# Removed folder: json

# %% [markdown]
# # Great ! Go to the next - and last - notebook !
