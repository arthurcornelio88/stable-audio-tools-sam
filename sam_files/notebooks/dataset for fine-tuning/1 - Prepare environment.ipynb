# %% [markdown]
# # 1 - Prepare environment

# %% [markdown]
# ## 1. Creating the .env file

# %% [markdown]
# ### a) Run the cell below to create the .env file

# %%
# %%bash
#
# echo "GITHUB_PROFILE_NAME=" > .env

# %% [markdown]
# ### b) Open the .env in :
# - sam_files/notebooks/dataset for fine-tuning/.env
# - ⚠️ **Insert your GitHub profile name**

# %% [markdown]
# ### c) Installing requirements

# %%
# run this once or restart the notebook
# %cd ../..
# Out:
# /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files

# %%
# Activate the environment
# !python -m venv myenv
# !source myenv/bin/activate
# Install dependencies out from requirements.txt
# %pip install --upgrade pip
# %pip install python-dotenv
# Out:
# Requirement already satisfied: pip in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (24.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install dependencies inside requirements.txt
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: nltk in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (3.7)
# Collecting pathlib (from -r requirements.txt (line 3))
#   Using cached pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: scikit-learn in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.3.1)
# Collecting google.cloud (from -r requirements.txt (line 5))
#   Downloading google_cloud-0.34.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: numpy>=1.21.0 in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: click in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nltk->-r requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: joblib in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nltk->-r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nltk->-r requirements.txt (line 2)) (2022.9.13)
# Requirement already satisfied: tqdm in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nltk->-r requirements.txt (line 2)) (4.64.1)
# Requirement already satisfied: scipy>=1.5.0 in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: six>=1.5 in /home/arthurcornelio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.16.0)
# Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Downloading google_cloud-0.34.0-py2.py3-none-any.whl (1.8 kB)
# Installing collected packages: pathlib, google.cloud
# Successfully installed google.cloud-0.34.0 pathlib-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Go to the next notebook
