# %% [markdown]
# # 4 - Downloading and renaming the audio files (.mp3)

# %% [markdown]
# ## 1. Open genre dataframe (.csv) in a table editor
#   - Open your .csv file in a Google Sheet or similar
#   - ⚠️ **Put a number '1' for dowloaded audio files, in `downloaded?` column**

# %% [markdown]
# ## 2. Create folders for processing downloaded audio files

# %% [markdown]
# ### a) Load .env variables

# %%
from dotenv import load_dotenv
import os

load_dotenv()

GITHUB_PROFILE_NAME = os.getenv('GITHUB_PROFILE_NAME')

# %% [markdown]
# ### b) Create processing folders
#   - `vo_{github-profile}`: where the final files will be placed
#   - `transition_{github-profile}` : where every renaming processing will be done
#   - `backup_{github-profile}` : put files from transition folder to here every 20 processed file

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

def create_folders():
    """
    Creates three folders (v0, transition, backup) within the 'audio_files' directory
    relative to the user's home directory and GitHub profile name.
    """

    # Automatically get the user's home directory
    home_dir = os.path.expanduser('~')

    # Capture the GitHub profile name from the environment variable
    github_profile_name = os.getenv('GITHUB_PROFILE_NAME')

    # Construct the base path for the audio_files directory
    base_path = os.path.join(home_dir, f'code/{github_profile_name}/stable-audio-tools-sam/sam_files/audio_files/_processing')

    # Define the folder names to be created
    v0 = f"v0_{github_profile_name}"
    transition = f"transition_{github_profile_name}"
    backup = f"backup_{github_profile_name}"
    folders = [v0, transition, backup]

    # Create the directories
    for folder in folders:
        folder_path = os.path.join(base_path, folder)

        # Check if the folder already exists
        if not os.path.exists(folder_path):
            # Create the folder if it doesn't exist
            os.makedirs(folder_path)
            print(f"Created folder: {folder_path}")
        else:
            print(f"Folder already exists: {folder_path}")

# Run the function to create the folders
create_folders()
# Out:
# Created folder: /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files/audio_files/_processing/v0_arthurcornelio88
# Created folder: /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files/audio_files/_processing/transition_arthurcornelio88
# Created folder: /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files/audio_files/_processing/backup_arthurcornelio88

# %% [markdown]
# ## 3. Download audio files
#   - We recommend that you download 10 or 20 files at a time.
#   - You will alternate between step 3 and 4 until you finish the download of all files. Good luck !
#   - ⚠️ If you can't download a file, you need to erase its .JSON file

# %% [markdown]
# ## 4. Rename files

# %% [markdown]
# ### 4.1. Run the script "rename_files.py"

# %% [markdown]
# - ⚠️ Set the path just once !
# - It needs to be ../stable-audio-tools-sam/sam_files
# - If don't, restart the notebook and run this cell below again

# %%
# %cd ..
# %cd ..
# Out:
# /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files/notebooks
# /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files

# %%
#rename_files_by_dataframe

# !python scripts/rename_files_by_url_key.py \
    audio_files/_processing/transition_{GITHUB_PROFILE_NAME}/ \
    dataframes/filtered_by_genre/500_classical_tracks.csv
# Out:
# No matching file found for URL key '116199'
# No matching file found for URL key '136788'
# No matching file found for URL key '169621'
# No matching file found for URL key '200663'
# No matching file found for URL key '188794'
# No matching file found for URL key '124265'
# No matching file found for URL key '136824'
# No matching file found for URL key '33106'
# No matching file found for URL key '140894'
# No matching file found for URL key '147979'
# No matching file found for URL key '111355'
# No matching file found for URL key '145038'
# No matching file found for URL key '145636'
# No matching file found for URL key '115672'
# No matching file found for URL key '178316'
# No matching file found for URL key '158250'
# No matching file found for URL key '168168'
# No matching file found for URL key '9835'
# No matching file found for URL key '201042'
# No matching file found for URL key '201530'
# No matching file found for URL key '197089'
# No matching file found for URL key '188266'
# No matching file found for URL key '219961'
# No matching file found for URL key '9489'
# No matching file found for URL key '222056'
# No matching file found for URL key '222482'
# No matching file found for URL key '212720'
# No matching file found for URL key '113907'
# No matching file found for URL key '225723'
# No matching file found for URL key '225036'
# No matching file found for URL key '201840'
# No matching file found for URL key '223676'
# No matching file found for URL key '225035'
# No matching file found for URL key '202383'
# No matching file found for URL key '202372'
# No matching file found for URL key '122118'
# No matching file found for URL key '192841'
# No matching file found for URL key '113888'
# No matching file found for URL key '201837'
# No matching file found for URL key '11120'
# No matching file found for URL key '112623'
# No matching file found for URL key '227308'
# No matching file found for URL key '225755'
# No matching file found for URL key '214102'
# No matching file found for URL key '218762'
# No matching file found for URL key '8697'
# No matching file found for URL key '201831'
# No matching file found for URL key '12955'
# No matching file found for URL key '11258'
# No matching file found for URL key '8037'
# No matching file found for URL key '11222'
# No matching file found for URL key '150622'
# No matching file found for URL key '197578'
# No matching file found for URL key '112785'
# No matching file found for URL key '202380'
# No matching file found for URL key '192838'
# No matching file found for URL key '227835'
# No matching file found for URL key '227805'
# No matching file found for URL key '218335'
# No matching file found for URL key '201654'
# No matching file found for URL key '207071'
# No matching file found for URL key '219962'
# No matching file found for URL key '226184'
# No matching file found for URL key '192842'
# No matching file found for URL key '223082'
# No matching file found for URL key '223674'
# No matching file found for URL key '201839'
# No matching file found for URL key '203609'
# No matching file found for URL key '197085'
# No matching file found for URL key '221141'
# No matching file found for URL key '205323'
# No matching file found for URL key '201039'
# No matching file found for URL key '115231'
# No matching file found for URL key '177577'
# No matching file found for URL key '115973'
# No matching file found for URL key '203835'
# No matching file found for URL key '225114'
# No matching file found for URL key '141467'
# No matching file found for URL key '203756'
# No matching file found for URL key '227182'
# No matching file found for URL key '111206'
# No matching file found for URL key '10524'
# No matching file found for URL key '227802'
# No matching file found for URL key '227803'
# No matching file found for URL key '227806'
# No matching file found for URL key '227827'
# No matching file found for URL key '227804'
# No matching file found for URL key '227836'
# No matching file found for URL key '227834'
# No matching file found for URL key '216329'
# No matching file found for URL key '186817'
# No matching file found for URL key '116955'
# No matching file found for URL key '224432'
# No matching file found for URL key '149998'
# No matching file found for URL key '141580'
# No matching file found for URL key '197087'
# No matching file found for URL key '201036'
# No matching file found for URL key '199956'
# No matching file found for URL key '201838'
# No matching file found for URL key '150146'
# No matching file found for URL key '150013'
# No matching file found for URL key '208164'
# No matching file found for URL key '218347'
# No matching file found for URL key '203754'
# No matching file found for URL key '123894'
# No matching file found for URL key '225722'
# No matching file found for URL key '205321'
# No matching file found for URL key '141289'
# No matching file found for URL key '176148'
# No matching file found for URL key '227821'
# No matching file found for URL key '15474'
# No matching file found for URL key '225666'
# No matching file found for URL key '210366'
# No matching file found for URL key '216336'
# No matching file found for URL key '203771'
# No matching file found for URL key '121841'
# No matching file found for URL key '194766'
# No matching file found for URL key '197086'
# No matching file found for URL key '202382'
# No matching file found for URL key '214863'
# No matching file found for URL key '220167'
# No matching file found for URL key '194370'
# No matching file found for URL key '142564'
# No matching file found for URL key '197577'
# No matching file found for URL key '9834'
# No matching file found for URL key '197083'
# No matching file found for URL key '226808'
# No matching file found for URL key '205627'
# No matching file found for URL key '224282'
# No matching file found for URL key '201037'
# No matching file found for URL key '216330'
# No matching file found for URL key '205318'
# No matching file found for URL key '202370'
# No matching file found for URL key '11218'
# No matching file found for URL key '223675'
# No matching file found for URL key '202378'
# No matching file found for URL key '224434'
# No matching file found for URL key '224653'
# No matching file found for URL key '225668'
# No matching file found for URL key '227828'
# No matching file found for URL key '227819'
# No matching file found for URL key '227831'
# No matching file found for URL key '227825'
# No matching file found for URL key '227801'
# No matching file found for URL key '227826'
# No matching file found for URL key '227829'
# No matching file found for URL key '227833'
# No matching file found for URL key '227830'
# No matching file found for URL key '227832'
# No matching file found for URL key '222298'
# No matching file found for URL key '143149'
# No matching file found for URL key '128376'
# No matching file found for URL key '178313'
# No matching file found for URL key '222166'
# No matching file found for URL key '216328'
# No matching file found for URL key '124112'
# No matching file found for URL key '226845'
# No matching file found for URL key '197576'
# No matching file found for URL key '142837'
# No matching file found for URL key '207193'
# No matching file found for URL key '203757'
# No matching file found for URL key '201038'
# No matching file found for URL key '205322'
# No matching file found for URL key '203831'
# No matching file found for URL key '225764'
# No matching file found for URL key '113676'
# No matching file found for URL key '180911'
# No matching file found for URL key '192840'
# No matching file found for URL key '202369'
# No matching file found for URL key '205576'
# No matching file found for URL key '227807'
# No matching file found for URL key '189206'
# No matching file found for URL key '201836'
# No matching file found for URL key '118668'
# No matching file found for URL key '205319'
# No matching file found for URL key '221812'
# No matching file found for URL key '194441'
# No matching file found for URL key '142600'
# No matching file found for URL key '218336'
# No matching file found for URL key '166273'
# No matching file found for URL key '190862'
# No matching file found for URL key '178308'
# No matching file found for URL key '202381'
# No matching file found for URL key '12006'
# No matching file found for URL key '158083'
# No matching file found for URL key '216331'
# No matching file found for URL key '222851'
# No matching file found for URL key '202368'
# No matching file found for URL key '222483'
# No matching file found for URL key '99499'
# No matching file found for URL key '199494'
# No matching file found for URL key '227135'
# No matching file found for URL key '187364'
# No matching file found for URL key '202371'
# No matching file found for URL key '6672'
# No matching file found for URL key '210063'
# No matching file found for URL key '204849'
# No matching file found for URL key '112841'
# No matching file found for URL key '111679'
# No matching file found for URL key '215740'
# No matching file found for URL key '197575'
# No matching file found for URL key '186758'
# No matching file found for URL key '210868'
# No matching file found for URL key '227133'
# No matching file found for URL key '221782'
# No matching file found for URL key '6674'
# No matching file found for URL key '178310'
# No matching file found for URL key '123895'
# No matching file found for URL key '111353'
# No matching file found for URL key '186761'
# No matching file found for URL key '225617'
# No matching file found for URL key '174160'
# No matching file found for URL key '124488'
# No matching file found for URL key '215975'
# No matching file found for URL key '190553'
# No matching file found for URL key '218341'
# No matching file found for URL key '202379'
# No matching file found for URL key '200132'
# No matching file found for URL key '154533'
# No matching file found for URL key '193847'
# No matching file found for URL key '204294'
# No matching file found for URL key '144435'
# No matching file found for URL key '226275'
# No matching file found for URL key '113909'
# No matching file found for URL key '199952'
# No matching file found for URL key '209547'
# No matching file found for URL key '116200'
# No matching file found for URL key '200149'
# No matching file found for URL key '135518'
# No matching file found for URL key '153643'
# No matching file found for URL key '150084'
# No matching file found for URL key '187363'
# No matching file found for URL key '189905'
# No matching file found for URL key '221783'
# No matching file found for URL key '227138'
# No matching file found for URL key '21257'
# No matching file found for URL key '193855'
# No matching file found for URL key '194801'
# No matching file found for URL key '205574'
# No matching file found for URL key '178304'
# No matching file found for URL key '218340'
# No matching file found for URL key '136110'
# No matching file found for URL key '178285'
# No matching file found for URL key '188311'
# No matching file found for URL key '221777'
# No matching file found for URL key '203834'
# No matching file found for URL key '219418'
# No matching file found for URL key '194442'
# No matching file found for URL key '226914'
# No matching file found for URL key '219953'
# No matching file found for URL key '191898'
# No matching file found for URL key '186813'
# No matching file found for URL key '121041'
# No matching file found for URL key '174155'
# No matching file found for URL key '221776'
# No matching file found for URL key '10782'
# No matching file found for URL key '211472'
# No matching file found for URL key '199297'
# No matching file found for URL key '225625'
# No matching file found for URL key '129210'
# No matching file found for URL key '227127'
# No matching file found for URL key '192839'
# No matching file found for URL key '189777'
# No matching file found for URL key '150106'
# No matching file found for URL key '205965'
# No matching file found for URL key '128378'
# No matching file found for URL key '214352'
# No matching file found for URL key '215741'
# No matching file found for URL key '202223'
# No matching file found for URL key '210375'
# No matching file found for URL key '227795'
# No matching file found for URL key '227796'
# No matching file found for URL key '227817'
# No matching file found for URL key '227797'
# No matching file found for URL key '227808'
# No matching file found for URL key '227822'
# No matching file found for URL key '227820'
# No matching file found for URL key '227824'
# No matching file found for URL key '227815'
# No matching file found for URL key '227809'
# No matching file found for URL key '227818'
# No matching file found for URL key '227811'
# No matching file found for URL key '227203'
# No matching file found for URL key '227814'
# No matching file found for URL key '227823'
# No matching file found for URL key '200136'
# No matching file found for URL key '177545'
# No matching file found for URL key '224660'
# No matching file found for URL key '182223'
# No matching file found for URL key '150109'
# No matching file found for URL key '218827'
# No matching file found for URL key '216343'
# No matching file found for URL key '115496'
# No matching file found for URL key '208297'
# No matching file found for URL key '176770'
# No matching file found for URL key '143535'
# No matching file found for URL key '115480'
# No matching file found for URL key '225713'
# No matching file found for URL key '191319'
# No matching file found for URL key '178309'
# No matching file found for URL key '204156'
# No matching file found for URL key '186760'
# No matching file found for URL key '194445'
# No matching file found for URL key '221781'
# No matching file found for URL key '9785'
# No matching file found for URL key '112845'
# No matching file found for URL key '200131'
# No matching file found for URL key '193852'
# No matching file found for URL key '177578'
# No matching file found for URL key '187362'
# No matching file found for URL key '201375'
# No matching file found for URL key '191896'
# No matching file found for URL key '215739'
# No matching file found for URL key '186932'
# No matching file found for URL key '186759'
# No matching file found for URL key '225670'
# No matching file found for URL key '141736'
# No matching file found for URL key '223373'
# No matching file found for URL key '141480'
# No matching file found for URL key '187373'
# No matching file found for URL key '174161'
# No matching file found for URL key '219596'
# No matching file found for URL key '219963'
# No matching file found for URL key '150475'
# No matching file found for URL key '221903'
# No matching file found for URL key '194443'
# No matching file found for URL key '216986'
# No matching file found for URL key '177579'
# No matching file found for URL key '226813'
# No matching file found for URL key '225656'
# No matching file found for URL key '220873'
# No matching file found for URL key '221780'
# No matching file found for URL key '221137'
# No matching file found for URL key '225631'
# No matching file found for URL key '130489'
# No matching file found for URL key '142264'
# No matching file found for URL key '215103'
# No matching file found for URL key '223579'
# No matching file found for URL key '187171'
# No matching file found for URL key '112621'
# No matching file found for URL key '11545'
# No matching file found for URL key '202139'
# No matching file found for URL key '150606'
# No matching file found for URL key '6673'
# No matching file found for URL key '119523'
# No matching file found for URL key '126916'
# No matching file found for URL key '212902'
# No matching file found for URL key '180908'
# No matching file found for URL key '178297'
# No matching file found for URL key '180907'
# No matching file found for URL key '200127'
# No matching file found for URL key '111724'
# No matching file found for URL key '178303'
# No matching file found for URL key '225272'
# No matching file found for URL key '210400'
# No matching file found for URL key '221116'
# No matching file found for URL key '216337'
# No matching file found for URL key '199232'
# No matching file found for URL key '142481'
# No matching file found for URL key '209060'
# No matching file found for URL key '176718'
# No matching file found for URL key '219623'
# No matching file found for URL key '200147'
# No matching file found for URL key '219964'
# No matching file found for URL key '176719'
# No matching file found for URL key '158999'
# No matching file found for URL key '221779'
# No matching file found for URL key '226399'
# No matching file found for URL key '226392'
# No matching file found for URL key '204865'
# No matching file found for URL key '188392'
# No matching file found for URL key '226396'
# No matching file found for URL key '123922'
# No matching file found for URL key '212490'
# No matching file found for URL key '225116'
# No matching file found for URL key '119948'
# No matching file found for URL key '175535'
# No matching file found for URL key '174136'
# No matching file found for URL key '141920'
# No matching file found for URL key '224239'
# No matching file found for URL key '169153'
# No matching file found for URL key '223893'
# No matching file found for URL key '227810'
# No matching file found for URL key '227798'
# No matching file found for URL key '227799'
# No matching file found for URL key '227812'
# No matching file found for URL key '205579'
# No matching file found for URL key '176768'
# No matching file found for URL key '176566'
# No matching file found for URL key '110055'
# No matching file found for URL key '189907'
# No matching file found for URL key '183738'
# No matching file found for URL key '222921'
# No matching file found for URL key '158075'
# No matching file found for URL key '212491'
# No matching file found for URL key '222455'
# No matching file found for URL key '190674'
# No matching file found for URL key '209875'
# No matching file found for URL key '226183'
# No matching file found for URL key '224304'
# No matching file found for URL key '178300'
# No matching file found for URL key '200502'
# No matching file found for URL key '178311'
# No matching file found for URL key '116954'
# No matching file found for URL key '116956'
# No matching file found for URL key '178307'
# No matching file found for URL key '103662'
# No matching file found for URL key '203034'
# No matching file found for URL key '221567'
# No matching file found for URL key '225927'
# No matching file found for URL key '226627'
# No matching file found for URL key '158068'
# No matching file found for URL key '8756'
# No matching file found for URL key '178305'
# No matching file found for URL key '189904'
# No matching file found for URL key '177576'
# No matching file found for URL key '176769'
# No matching file found for URL key '212726'
# No matching file found for URL key '222923'
# No matching file found for URL key '136898'
# No matching file found for URL key '198981'
# No matching file found for URL key '216335'
# No matching file found for URL key '225629'
# No matching file found for URL key '141121'
# No matching file found for URL key '197736'
# No matching file found for URL key '203124'
# No matching file found for URL key '142259'
# No matching file found for URL key '222463'
# No matching file found for URL key '12953'
# No matching file found for URL key '224639'
# No matching file found for URL key '225667'
# No matching file found for URL key '9625'
# No matching file found for URL key '185593'
# No matching file found for URL key '178302'
# No matching file found for URL key '182220'
# No matching file found for URL key '182222'
# No matching file found for URL key '175536'
# No matching file found for URL key '178306'
# No matching file found for URL key '205573'
# No matching file found for URL key '221778'
# No matching file found for URL key '121177'
# No matching file found for URL key '16026'
# No matching file found for URL key '180627'
# No matching file found for URL key '120698'
# No matching file found for URL key '178284'
# No matching file found for URL key '147373'
# No matching file found for URL key '226908'
# No matching file found for URL key '111860'
# No matching file found for URL key '168574'
# No matching file found for URL key '148564'
# No matching file found for URL key '7573'
# No matching file found for URL key '224796'
# No matching file found for URL key '116798'
# No matching file found for URL key '187639'
# No matching file found for URL key '115481'
# No matching file found for URL key '200229'
# No matching file found for URL key '218387'
# No matching file found for URL key '193874'
# No matching file found for URL key '212561'
# No matching file found for URL key '141472'
# No matching file found for URL key '136831'
# No matching file found for URL key '166440'
# No matching file found for URL key '178312'
# No matching file found for URL key '225655'
# No matching file found for URL key '216338'
# No matching file found for URL key '203316'
# No matching file found for URL key '15021'
# No matching file found for URL key '121838'
# No matching file found for URL key '176723'
# No matching file found for URL key '225669'
# No matching file found for URL key '119940'
# No matching file found for URL key '226016'
# No matching file found for URL key '211470'
# No matching file found for URL key '174156'
# No matching file found for URL key '225922'
# No matching file found for URL key '224635'
# No matching file found for URL key '10709'
# No matching file found for URL key '142337'
# No matching file found for URL key '142554'
# No matching file found for URL key '150619'
# No matching file found for URL key '177542'
# No matching file found for URL key '157906'
# No matching file found for URL key '142838'
# No matching file found for URL key '146966'
# No matching file found for URL key '176535'
# No matching file found for URL key '210365'
# No matching file found for URL key '209034'
# No matching file found for URL key '177540'
# No matching file found for URL key '177541'
# No matching file found for URL key '200661'
# No matching file found for URL key '119952'
# No matching file found for URL key '12954'
# No matching file found for URL key '200146'
# No matching file found for URL key '158070'
# No matching file found for URL key '223332'
# No matching file found for URL key '166583'
# No matching file found for URL key '201208'
# No matching file found for URL key '178298'
# No matching file found for URL key '113661'
# No matching file found for URL key '174980'

# %% [markdown]
# ⚠️ You'll need to adjust the index after the first renaming turn :
#   - --start_index 20 , for files from 20 to 40

# %%
#rename_files.py

# !python scripts/rename_files.py \
    audio_files/_processing/transition_{GITHUB_PROFILE_NAME}/ \
    # --start_index 1
# Out:
# Renamed 'audio1test.mp3' to '1_audio1test.mp3'
# Renamed 'audio2test.mp3' to '2_audio2test.mp3'
# Renamed 'audio3test.mp3' to '3_audio3test.mp3'
# Renamed 'audio4test.mp3' to '4_audio4test.mp3'
# Renamed 'audio5test.mp3' to '5_audio5test.mp3'
# Renamed 'audio6test.mp3' to '6_audio6test.mp3'
# Renamed 'audio7test.mp3' to '7_audio7test.mp3'
# Renamed 'audio8test.mp3' to '8_audio8test.mp3'
# Renamed 'audio9test.mp3' to '9_audio9test.mp3'
# Renamed 'audio10test.mp3' to '10_audio10test.mp3'

# %% [markdown]
# - If you need to rename an existing file, use the script "rename_and_adjust.py"

# %%
# simple renaming and adjusting neighbors files
## !python rename_and_adjust.py <folder_path> <target_file_name> <target_index> [--add] [--undo]

# !python scripts/rename_and_adjust.py \
    audio_files/_processing/transition_{GITHUB_PROFILE_NAME} \
    1_audio1test.mp3 \
    8

# %% [markdown]
# - If you need to add a new file, use the script "rename_and_adjust.py" with the flag --add

# %%
# adding one new file
# !python scripts/rename_and_adjust.py \
    audio_files/_processing/transition_{GITHUB_PROFILE_NAME} \
    audio10test.mp3 \
    8 \
    --add

# %% [markdown]
#   - If you need to undo the last modification

# %%
# to undo the renaming
# !python \
    scripts/rename_and_adjust.py \
   audio_files/_processing/transition_{GITHUB_PROFILE_NAME} \
    "placeholder" \
    0 \
    --undo

# %% [markdown]
#   - Or if you want to start from zero and erase the prefixes, use "remove_prefixes.py"

# %%
#remove prefixes
# !python scripts/remove_prefixes.py audio_files/_processing/transition_{GITHUB_PROFILE_NAME}

# %% [markdown]
# ### 4.2. Move files
#
# - Move renamed files (in /transition) to /v0_yourname

# %%
# move renamed files (in /transition) to /v0_yourname

# !mv audio_files/_processing/transition_{GITHUB_PROFILE_NAME}/* audio_files/_processing/v0_{GITHUB_PROFILE_NAME}/

# %% [markdown]
# ⚠️ If you need to undo the last operation

# %%
# !mv audio_files/_processing/v0_{GITHUB_PROFILE_NAME}/* audio_files/_processing/transition_{GITHUB_PROFILE_NAME}/

# %% [markdown]
# ## 5. Create final folder

# %% [markdown]
# ### 5.1. Verify consistency
# ⚠️ Before it, you'll need to verify the consistency of your :
# - Renamed audiofiles
# - .json files
# - .csv rows

# %%
'''
python script_name.py /home/user/data/audio_files \
    --csv /home/user/data/titles.csv \
    --json_folder /home/user/data/json_files
'''

# !python scripts/verify_csv-audio-json_files.py \
    audio_files/_processing/v0_{GITHUB_PROFILE_NAME} \
    --csv dataframes/filtered_by_genre/500_classical_tracks.csv \
    --json_folder json/json_classical/
# Out:
# WARNING:root:Row 410: Failed to download file with URL key '225927'
# WARNING:root:Row 475: Failed to download file with URL key '225922'
#
# Failed downloads:
# Row 410: Failed to download file with URL key '225927'
# Row 475: Failed to download file with URL key '225922'

# %% [markdown]
# ### 5.2. Saving "file_count" on .env

# %%
# %%bash
#
# file_count=$(ls -1 audio_files/_processing/v0_${GITHUB_PROFILE_NAME} | wc -l)
# echo "file_count=$file_count" >> "notebooks/dataset for fine-tuning/.env"

# %% [markdown]
# ### 5.3. Create final folder, move processed files into it and backup folder

# %%
# %%bash
#
# # Source the .env file to load the variables into the environment
# source "notebooks/dataset for fine-tuning/.env"
#
# # Access the genre variable directly
# genre=$genre_folder
#
# # Create the final folder name
# final_folder_name="${file_count}_${genre}_audiofiles"
#
# # Create the new folder
# mkdir audio_files/by_genre
# mkdir audio_files/by_genre/"$final_folder_name"
#
# ### V0 to Backup with timestamp ###
#
# # Create the backup folder (if it doesn't exist)
# mkdir -p audio_files/final_backup
#
# # Get the current timestamp
# timestamp=$(date +"%Y-%m-%d_%H-%M-%S")
#
# # Create the backup folder name with the timestamp
# backup_folder_name="backup_${GITHUB_PROFILE_NAME}_${timestamp}"
#
# # Create the full backup directory path
# mkdir -p audio_files/final_backup/$backup_folder_name
#
# # Copy all files from the source directory to the destination
# cp -r audio_files/_processing/v0_${GITHUB_PROFILE_NAME}/* audio_files/final_backup/$backup_folder_name/
#
# ### V0 to Final Folder ###
#
# # Copy all files from the source directory to the destination
# cp -r audio_files/_processing/v0_${GITHUB_PROFILE_NAME}/* audio_files/final_backup/$backup_folder_name/
#
# # Move all files from the source directory to the final folder
# mv audio_files/_processing/v0_${GITHUB_PROFILE_NAME}/* audio_files/by_genre/"$final_folder_name"/
# Out:
# bash: line 4: sam_files/notebooks/dataset: No such file or directory

# %% [markdown]
# ### 5.4. Create .csv "checked"

# %% [markdown]
# - Donwload your dataframe "all-checked" (all values in "Downloaded?" column are '1') as .csv
# - Rename it like your-dataframe-**checked**
# - Move it to /sam_files/dataframes/checked

# %% [markdown]
# ### 5.5. Remove operational folders

# %%
# %cd /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files

import shutil
import os

github_profile_name = GITHUB_PROFILE_NAME  # Replace with your actual GitHub profile name

# Construct the full paths to the folders
transition_folder = f"audio_files/_processing/transition_{github_profile_name}"
v0_folder = f"audio_files/_processing/v0_{github_profile_name}"
backup_folder = f"audio_files/_processing/backup_{github_profile_name}"

# Remove the folders using shutil.rmtree
for folder in [transition_folder, v0_folder, backup_folder]:
    try:
        shutil.rmtree(folder)
        print(f"Removed folder: {folder}")
    except OSError as e:
        print(f"Error removing folder {folder}: {e}")
# Out:
# /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files
# Removed folder: audio_files/_processing/transition_arthurcornelio88
# Removed folder: audio_files/_processing/v0_arthurcornelio88
# Removed folder: audio_files/_processing/backup_arthurcornelio88

# %% [markdown]
# # Great ! Go to the next - and last - notebook !
