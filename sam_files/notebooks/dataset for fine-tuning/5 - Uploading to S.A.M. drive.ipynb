# %% [markdown]
# # 5 - Uploading to S.A.M. drive

# %% [markdown]
# ## 1. Load .env variables

# %%
from dotenv import load_dotenv
import os

load_dotenv()

GITHUB_PROFILE_NAME = os.getenv('GITHUB_PROFILE_NAME')
genre_folder = os.getenv('genre_folder')
file_count = os.getenv('file_count')

# %% [markdown]
# ### 1.3. Move manually your .JSON credential
#   - Put it in /sam_files
#   - Open the .env for sam_files (sam_files/notebooks/dataset for fine-tuning/.env)
#   - insert this line :
#     - `gdrive_api_json_path={path-for-json-credential.json}`

# %%
# %cd ..
# %cd ..
# Out:
# /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files/notebooks
# /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files

# %%
# %%bash
#
# # Replace with your actual bucket name
# bucket_name="sam-dataset"
#
# # Get the current timestamp
# timestamp=$(date +"%Y-%m-%d_%H-%M-%S")
#
# # Create the folder name within the bucket
# folder_name="${file_count}_${genre_folder}_files_${timestamp}"
#
# #capture variables
# echo "bucket_name=$bucket_name" >> "notebooks/dataset for fine-tuning/.env"
# echo "timestamp=$timestamp" >> "notebooks/dataset for fine-tuning/.env"
# echo "folder_name=$folder_name" >> "notebooks/dataset for fine-tuning/.env"
#
# # List of source folders you want to upload
# source_folders=("json" "dataframes" "audio_files")
#
# # Upload each folder to the bucket
# for source_folder in "${source_folders[@]}"
# do
#     gsutil -m cp -r -L "upload_log_${timestamp}.txt" "$source_folder" "gs://$bucket_name/$folder_name/"
# done
# Out:
# Copying file://json/json_test/8_audio8test.json [Content-Type=application/json]...
# Copying file://json/json_test/5_audio5test.json [Content-Type=application/json]...
# Copying file://json/json_test/1_audio1test.json [Content-Type=application/json]...
# Copying file://json/json_test/7_audio7test.json [Content-Type=application/json]...
# Copying file://json/json_test/9_audio9test.json [Content-Type=application/json]...
# Copying file://json/json_test/4_audio4test.json [Content-Type=application/json]...
# Copying file://json/json_test/6_audio6test.json [Content-Type=application/json]...
# Copying file://json/json_test/3_audio3test.json [Content-Type=application/json]...
# Copying file://json/json_test/2_audio2test.json [Content-Type=application/json]...
# Copying file://json/json_test/10_audio10test.json [Content-Type=application/json]...
# - [10/10 files][  2.0 KiB/  2.0 KiB] 100% Done
# Operation completed over 10 objects/2.0 KiB.
# Copying file://dataframes/scrapped/cleaned-export-10k.csv [Content-Type=text/csv]...
# Copying file://dataframes/scrapped/Export 10k.xlsx [Content-Type=application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]...
# Copying file://dataframes/scrapped/export-10k.csv [Content-Type=text/csv]...
# Copying file://dataframes/scrapped/cleaned_filtered-export-10k.xlsx [Content-Type=application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]...
# Copying file://dataframes/filtered_by_genre/500_lofi_tracks.csv [Content-Type=text/csv]...
# Copying file://dataframes/checked/test_df_notebook_checked.csv [Content-Type=text/csv]...
# Copying file://dataframes/filtered_by_genre/500_classical_tracks.csv [Content-Type=text/csv]...
# Copying file://dataframes/scrapped/Bon _Export_20k_full_tags.csv [Content-Type=text/csv]...
# Copying file://dataframes/scrapped/Export 10k.xlsx - Sheet1.csv:Zone.Identifier [Content-Type=application/octet-stream]...
# Copying file://dataframes/scrapped/20240731_df_processed-bon-exp-20k-full.csv [Content-Type=text/csv]...
# Copying file://dataframes/scrapped/scrapping-analyse.ipynb [Content-Type=application/octet-stream]...
# Copying file://dataframes/filtered_by_genre/test_df_notebook.csv [Content-Type=text/csv]...
# Copying file://dataframes/scrapped/Export 10k.xlsx:Zone.Identifier [Content-Type=application/octet-stream]...
# - [13/13 files][ 25.0 MiB/ 25.0 MiB] 100% Done
# Operation completed over 13 objects/25.0 MiB.
# Copying file://audio_files/final_backup/backup_arthurcornelio88_2024-08-13_17-49-54/2_audio2test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/final_backup/backup_arthurcornelio88_2024-08-13_17-49-54/1_audio1test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/final_backup/backup_arthurcornelio88_2024-08-13_17-49-54/9_audio9test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/10_test_audiofiles/9_audio9test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/final_backup/backup_arthurcornelio88_2024-08-13_17-49-54/3_audio3test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/10_test_audiofiles/4_audio4test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/10_test_audiofiles/2_audio2test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/final_backup/backup_arthurcornelio88_2024-08-13_17-49-54/8_audio8test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/final_backup/backup_arthurcornelio88_2024-08-13_17-49-54/4_audio4test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/final_backup/backup_arthurcornelio88_2024-08-13_17-49-54/7_audio7test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/10_test_audiofiles/1_audio1test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/10_test_audiofiles/8_audio8test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/final_backup/backup_arthurcornelio88_2024-08-13_17-49-54/10_audio10test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/10_test_audiofiles/7_audio7test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/10_test_audiofiles/5_audio5test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/10_test_audiofiles/10_audio10test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/10_test_audiofiles/3_audio3test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/final_backup/backup_arthurcornelio88_2024-08-13_17-49-54/5_audio5test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/final_backup/backup_arthurcornelio88_2024-08-13_17-49-54/6_audio6test.mp3 [Content-Type=audio/mpeg]...
# Copying file://audio_files/by_genre/10_test_audiofiles/6_audio6test.mp3 [Content-Type=audio/mpeg]...
# / [20/20 files][ 99.0 MiB/ 99.0 MiB] 100% Done   1.8 MiB/s ETA 00:00:00
# Operation completed over 20 objects/99.0 MiB.

# %%
# !pwd
# Out:
# /home/arthurcornelio/code/arthurcornelio88/stable-audio-tools-sam/sam_files

# %%
from google.cloud import storage
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv(dotenv_path='notebooks/dataset for fine-tuning/.env')

# Access the variables from the .env file
bucket_name = os.getenv('bucket_name')
folder_name = os.getenv('folder_name')

def verify_upload(bucket_name, folder_name, source_folders):
    """Verifies if the specified folder and its subfolders exist in the given GCS bucket."""

    # Get the path to your service account credentials JSON file from the environment variable
    credentials_path = os.getenv('gdrive_api_json_path')

    # Explicitly create the storage client using the service account credentials
    storage_client = storage.Client.from_service_account_json(credentials_path)

    bucket = storage_client.bucket(bucket_name)

    # Check if the main folder exists
    blobs = list(bucket.list_blobs(prefix=folder_name + '/'))
    if not blobs:
        print(f"Upload failed or incomplete. Main folder '{folder_name}' not found in bucket '{bucket_name}'.")
        return  # Stop further checks if the main folder is missing

    # Check for the existence of each subfolder within the main folder
    for source_folder in source_folders:
        blobs = list(bucket.list_blobs(prefix=f"{folder_name}/{source_folder}/"))

        if blobs:
            print(f"Upload successful! Subfolder '{source_folder}' and its contents found in bucket '{bucket_name}' under '{folder_name}'.")
            # (Optional) You can iterate through 'blobs' to list individual files if needed
            # for blob in blobs:
            #   print(f"  - {blob.name}")
        else:
            print(f"Upload failed or incomplete. Subfolder '{source_folder}' not found in bucket '{bucket_name}' under '{folder_name}'.")

# List of source folders you want to upload
source_folders = [
    'json',
    'dataframes/checked',
    'dataframes/filtered_by_genre',
    'audio_files/by_genre',
    'audio_files/final_backup',
]

verify_upload(bucket_name, folder_name, source_folders)
# Out:
# Upload successful! Subfolder 'json' and its contents found in bucket 'sam-dataset' under '10_test_files_2024-08-13_18-26-37'.
# Upload successful! Subfolder 'dataframes/checked' and its contents found in bucket 'sam-dataset' under '10_test_files_2024-08-13_18-26-37'.
# Upload successful! Subfolder 'dataframes/filtered_by_genre' and its contents found in bucket 'sam-dataset' under '10_test_files_2024-08-13_18-26-37'.
# Upload successful! Subfolder 'audio_files/by_genre' and its contents found in bucket 'sam-dataset' under '10_test_files_2024-08-13_18-26-37'.
# Upload successful! Subfolder 'audio_files/final_backup' and its contents found in bucket 'sam-dataset' under '10_test_files_2024-08-13_18-26-37'.

# %%
# %%bash
#
# # Delete the folders and their contents
# rm -rf audio_files/final_backup audio_files/by_genre json/*

# %%
push to git...

# %% [markdown]
# # All done, bravo ! (by Arthur Cornélio, 12th August 2024)
